# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import logging
logging.basicConfig(level=logging.INFO)

# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# INFO:pytorch_pretrained_bert.tokenization:loading vocabulary file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /home/ubuntu/.pytorch_pretrained_bert/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084

# %%
x = torch.rand(16, 50)
y = torch.randn(16, 50)

# %%
torch.add(x,y)
# Out:
# tensor([[-3.6285e-01,  2.1353e+00,  1.3635e+00,  4.5509e-01,  2.9611e+00,
#          -3.4002e-01, -1.1033e-01,  1.7823e+00, -2.0549e+00,  1.8160e+00,
#           9.1798e-01, -1.3519e-02, -3.8176e-01, -2.5720e-01,  8.2993e-01,
#          -3.7678e-01,  8.3064e-01,  4.0142e-02, -7.2786e-01, -6.3016e-01,
#          -1.5183e+00,  5.8611e-01,  8.8385e-01,  1.4353e+00,  6.1886e-01,
#           1.8254e+00,  1.1450e-01,  1.1755e+00, -2.4351e-01, -8.3609e-01,
#           1.2840e+00,  3.7152e-01,  4.8241e-01,  7.6734e-01, -7.7852e-01,
#           1.0632e+00,  4.5449e-01,  1.0960e+00, -3.1369e-01,  1.8546e+00,
#           2.6766e+00, -1.2334e+00,  2.8940e+00,  1.6867e+00,  1.7893e+00,
#          -1.2308e+00,  5.0151e-01,  1.2479e+00,  5.3214e-01,  7.6085e-01],
#         [-1.5900e-01, -4.4692e-01, -5.1216e-01,  5.0966e-01,  1.6048e+00,
#          -4.3329e-01,  6.2193e-01,  2.0520e+00, -1.5548e+00,  1.4388e+00,
#           5.8363e-01,  6.0960e-01,  7.5370e-01, -8.0622e-01,  3.9439e-01,
#          -1.3045e+00,  2.1670e+00, -1.6960e+00,  2.1956e+00,  3.6572e-01,
#           1.1008e-02,  2.1191e+00,  8.2698e-01,  2.3585e+00,  4.6341e-01,
#          -3.1984e-01,  1.1105e-01,  1.9618e+00,  2.0191e+00,  1.0088e+00,
#           4.7275e-01, -1.3903e+00,  3.7355e-02,  1.3299e+00,  1.3087e+00,
#          -5.1889e-01, -1.7288e-01,  2.2123e+00,  7.2363e-01,  1.9607e+00,
#          -1.1964e-01, -1.0037e-01,  1.2002e+00, -1.8180e-01,  5.4014e-01,
#           1.2532e+00,  6.9231e-01,  7.8872e-01,  6.2922e-01,  1.2206e+00],
#         [ 5.0691e-01,  2.6297e-01,  5.6971e-01,  9.2408e-01, -1.0205e+00,
#           4.2648e-01,  7.1538e-02, -1.7968e-01,  9.8479e-01, -1.6409e+00,
#           5.3717e-01, -1.4734e+00,  2.2202e-01,  3.5947e-01,  4.8976e-01,
#          -4.6612e-01,  2.2134e-01,  1.2165e+00,  3.0426e-01,  7.0925e-01,
#           2.1195e+00, -1.5557e-01, -1.3125e+00, -1.5853e-01,  4.4669e-01,
#          -1.3110e+00, -2.3309e-01,  1.8011e-01,  1.9703e+00,  8.3158e-01,
#          -2.0274e+00,  7.2853e-01,  1.7775e+00,  1.6948e+00,  1.0709e+00,
#           3.9389e-01,  1.1180e+00,  6.2628e-01, -9.7357e-02,  1.8180e+00,
#           5.0520e-01,  1.5049e-02,  7.4885e-01,  9.7081e-01, -5.9084e-01,
#           6.5552e-01,  6.8289e-01, -2.5960e-01,  6.6521e-01,  1.0791e+00],
#         [ 1.9200e+00,  4.2384e-01, -1.4836e+00,  9.6927e-01, -2.9908e-01,
#           1.4102e+00,  7.8008e-01, -1.6881e+00, -4.7696e-03,  4.0570e-01,
#           2.2996e-01,  2.9279e-01,  5.4856e-01,  1.7565e+00,  4.3248e-01,
#           1.1462e+00, -1.9641e-01,  8.3900e-01,  7.0633e-02,  7.2742e-01,
#           8.1964e-01,  1.0488e+00,  1.6493e-01, -4.0205e-01, -8.7576e-01,
#           1.7636e-01,  6.1966e-02,  4.5907e-01,  1.0927e+00,  5.6858e-01,
#          -1.1944e-01,  1.1987e+00, -2.0328e-01,  1.9943e+00,  5.3803e-02,
#          -2.0827e-01, -7.3841e-01,  3.5269e-01, -5.2798e-01,  1.3385e+00,
#           2.3889e+00,  1.4531e+00,  8.2789e-01,  4.6665e-01, -9.4832e-02,
#           8.8923e-01,  2.4574e-01,  1.8936e+00, -6.9905e-01,  7.5391e-01],
#         [ 6.9181e-01, -3.0951e-01,  4.6344e-01, -8.8705e-01,  1.0623e+00,
#          -4.3381e-01, -7.8491e-01,  2.3039e-01,  9.3653e-01,  1.2966e+00,
#           8.0742e-03, -4.6171e-01,  1.5136e+00,  3.3333e+00, -7.8265e-02,
#           7.9900e-01,  1.6618e+00, -7.5649e-01,  4.4270e-01,  1.1709e+00,
#           6.3471e-01,  4.5036e-01, -7.4305e-01, -1.2828e+00,  1.8474e+00,
#           1.8169e+00, -1.2537e-01, -7.2715e-02,  3.9268e+00,  8.3343e-01,
#           7.8722e-01,  1.5643e+00,  2.5381e-01,  1.6926e+00,  8.2019e-01,
#           1.1128e+00,  1.3486e+00,  2.6669e+00,  1.0167e+00,  3.3289e-01,
#           1.6964e-01,  1.8437e+00,  5.2839e-01,  1.5240e+00,  1.0421e+00,
#          -1.4694e+00, -1.0213e-01,  1.0933e+00,  2.0355e+00, -5.6903e-01],
#         [ 7.2411e-02,  1.1491e+00,  9.7640e-01, -6.5515e-01,  1.2909e+00,
#           5.6822e-01, -5.1996e-01, -1.3600e+00,  8.1286e-01,  4.6130e-01,
#          -4.6815e-01, -9.2155e-02,  3.9985e-01,  1.6092e+00,  1.0850e+00,
#           2.7383e+00, -3.5724e-01, -4.4906e-01,  4.7264e-01,  3.8170e-01,
#           1.1857e+00,  6.0529e-01, -9.2957e-01, -1.1446e+00,  2.7131e+00,
#          -7.7376e-02,  2.2486e+00,  5.3714e-01,  2.9397e+00,  4.7167e-01,
#          -1.8996e-02,  1.0007e-01, -1.1606e+00,  2.7629e-01, -1.6368e+00,
#          -8.4069e-01,  8.0943e-01,  2.0945e+00,  4.0764e-01,  5.6417e-01,
#           2.9673e+00,  1.1044e+00,  1.0663e+00,  8.8984e-01,  9.4215e-01,
#           2.5004e-01,  1.0507e+00,  1.0021e+00,  4.8255e-01,  2.5113e+00],
#         [ 2.7518e+00, -3.4918e-01,  6.6937e-01,  9.6586e-01, -1.6249e-01,
#           6.8708e-01,  7.5022e-01,  5.6470e-01, -2.2998e-01, -5.4456e-01,
#           1.4772e+00, -4.4349e-02,  9.6094e-01,  1.1415e+00,  7.7687e-01,
#           2.2075e-01,  7.4674e-01,  1.7475e+00, -1.5614e+00, -1.5529e-01,
#          -8.3131e-01,  3.1610e-01, -1.2465e+00,  6.0040e-02, -6.1122e-02,
#          -4.2558e-01,  4.2445e-01,  2.5998e+00, -7.5813e-01,  3.3954e-01,
#           5.7547e-02,  8.6644e-01, -3.8669e-01,  2.1630e+00,  6.1941e-01,
#           9.3676e-01,  8.8314e-01,  1.2962e+00,  1.7067e+00, -4.3720e-01,
#          -5.9813e-01, -1.7138e+00,  1.3552e+00,  4.2225e-02,  3.9858e-02,
#          -8.5757e-01,  8.5433e-01,  1.7346e-01,  1.4481e+00,  1.0327e+00],
#         [ 2.3728e-01,  9.9057e-01, -7.0067e-01,  1.3490e+00,  9.9700e-01,
#           8.5741e-01,  1.2875e+00,  4.7140e-01, -1.1317e-01,  7.8298e-01,
#           1.9873e+00,  6.2932e-01,  4.7638e-01, -9.9016e-01,  9.4010e-01,
#          -1.3820e+00,  1.5133e+00, -1.2881e-01, -1.5534e-01, -1.2893e+00,
#           6.3061e-01, -1.3359e-01,  6.8049e-01, -2.1481e-01,  1.1597e+00,
#           2.7374e-01,  7.8803e-01,  4.3278e-01, -3.6685e-01,  2.3982e+00,
#           1.7992e+00, -1.4190e+00, -7.4203e-01,  7.7821e-01,  9.0480e-01,
#           1.6752e+00,  6.2155e-01,  6.8053e-01, -8.5370e-01,  8.3534e-01,
#           1.8953e+00,  1.2474e-01,  6.6165e-01,  2.0462e-01, -1.5729e+00,
#          -1.2827e-01,  9.5957e-01, -5.6901e-01, -8.0437e-01,  1.3542e+00],
#         [ 1.0051e-01,  1.5465e+00, -8.6587e-01, -5.9920e-01, -1.7590e+00,
#           1.9199e+00,  2.6359e+00,  6.6572e-01, -1.0177e+00,  9.6112e-01,
#           1.3426e+00, -3.4557e-01,  1.4205e+00,  3.9397e-01,  2.2021e+00,
#           1.4240e+00, -4.7452e-01, -9.5079e-01, -1.3707e+00,  1.4325e+00,
#           1.3977e+00,  1.6973e+00,  7.2058e-01,  1.4395e+00, -7.8537e-01,
#           7.8589e-01,  4.5484e-01,  3.0010e+00,  1.3416e+00,  6.3163e-01,
#          -1.5907e-01,  1.0753e+00,  8.1160e-01, -1.4163e+00, -1.2548e+00,
#           1.2011e+00,  6.4425e-01,  3.0940e+00, -8.1364e-01,  9.1865e-01,
#          -3.1755e-01,  1.5548e+00,  4.4975e-01, -6.0707e-01, -4.7826e-01,
#          -1.8624e-02,  2.1376e-01,  1.7746e+00,  2.4341e-01, -5.4026e-01],
#         [-7.7545e-02,  5.3753e-01,  1.3438e+00,  2.2971e+00,  1.1906e+00,
#           1.0988e+00, -4.1386e-01,  1.5163e+00, -9.1095e-01,  1.2806e+00,
#           5.2269e-01,  7.7851e-01,  2.7307e-01,  1.5611e+00, -3.3603e-01,
#          -9.6452e-01,  2.5279e+00,  9.3507e-01, -1.5685e+00,  1.2981e+00,
#           1.8579e+00,  2.7732e-01, -4.7003e-01,  2.7838e-01,  1.4915e+00,
#           3.4896e+00,  1.3570e+00, -2.9728e-01, -2.3132e-01,  2.4892e+00,
#          -1.1574e+00, -8.3204e-01,  2.8569e-02,  3.3358e-01,  1.0381e+00,
#          -2.8572e-02, -2.4504e-01, -6.9518e-02,  7.5158e-01,  8.4934e-04,
#           8.5284e-01,  1.2203e+00, -6.5434e-01,  9.3740e-01, -2.2710e+00,
#           3.8653e-01,  1.5909e-02,  2.0792e+00, -9.4031e-01,  5.5414e-01],
#         [ 1.6008e+00,  8.0385e-01,  9.7746e-01, -4.1347e-01,  1.4405e+00,
#           2.8035e-03, -1.2040e-01, -6.7136e-03,  9.3586e-01,  5.3169e-01,
#           9.6782e-01,  3.2286e+00, -8.9698e-01,  1.4512e-01,  8.0077e-01,
#          -2.8275e-01,  7.0967e-01,  9.2848e-01, -1.8632e+00,  1.7123e+00,
#           3.1874e-02,  1.1686e-01,  1.4581e+00, -5.9775e-01, -3.5357e-01,
#           3.9434e-01,  2.4660e+00, -5.7553e-02, -1.3133e+00, -5.8512e-01,
#          -3.4068e-01, -1.4298e-01, -8.0619e-01,  1.3004e+00,  1.6938e+00,
#          -1.0652e+00, -5.2686e-01, -1.9972e-01,  6.3727e-01,  7.2448e-01,
#           1.0157e+00,  1.3839e-01,  4.4064e-01,  1.6540e+00,  1.7944e-01,
#           7.1997e-01, -3.7561e-02,  9.8324e-01, -2.8585e-01,  8.3669e-01],
#         [ 2.2555e+00, -7.8872e-01, -8.4515e-01,  2.4070e+00, -4.2765e-01,
#          -6.3289e-01,  2.0074e+00,  4.6324e-01,  2.6771e-01,  1.7093e+00,
#           4.4092e+00, -4.6882e-01,  5.1427e-01,  1.7410e-01, -4.5494e-01,
#          -5.8457e-01,  8.4706e-01,  6.2846e-02,  1.1904e-01,  2.1595e+00,
#          -2.1058e-01, -3.7325e-01,  1.8125e+00,  1.1928e-02,  2.2205e+00,
#           1.2617e+00, -1.2173e-02,  2.5485e-01,  1.9622e+00,  1.0525e+00,
#           1.2403e+00, -9.8454e-01, -1.8999e+00, -9.6992e-01,  4.8401e-01,
#          -6.4535e-01,  2.0592e+00, -1.9573e-01,  9.4080e-01,  8.9209e-01,
#          -3.8136e-01, -8.9064e-01,  1.4568e+00, -1.1569e+00,  1.5339e+00,
#           1.3538e-01, -1.3839e+00, -3.4722e-02,  1.3254e+00,  8.4594e-01],
#         [ 6.9740e-01,  7.2093e-01,  8.3917e-01,  8.1861e-01,  8.7888e-01,
#           4.3114e-01,  1.4354e+00,  2.1354e+00,  1.5570e+00, -1.1600e+00,
#          -5.1471e-01,  5.1441e-02,  4.2851e-02,  1.6802e+00,  7.7266e-01,
#           2.6995e+00,  9.4118e-01,  1.7000e+00,  9.8091e-02,  1.0455e+00,
#          -1.3931e+00,  1.1501e+00,  5.8775e-01,  1.5235e+00,  1.0123e+00,
#           1.2819e-02,  1.7776e+00, -4.4569e-01, -9.3367e-01,  6.6978e-01,
#           2.7933e+00,  6.3765e-01, -8.4451e-01, -1.3445e-01,  1.5289e+00,
#          -4.2950e-01,  7.6630e-01,  1.6439e+00,  1.6076e+00, -5.8801e-01,
#           8.8877e-01,  6.3137e-02,  5.5171e-01, -7.9634e-01,  8.2384e-01,
#           1.4205e+00, -3.1032e-01,  1.0848e+00,  1.6420e+00, -1.1065e-01],
#         [ 2.3396e-01,  4.7044e-01,  5.9884e-01,  5.0423e-01,  2.1089e+00,
#           1.6836e+00, -1.2979e+00,  1.7689e+00,  1.1808e+00,  1.9491e+00,
#           2.2171e-01,  2.0420e+00,  6.0681e-01,  2.2138e+00, -1.2369e+00,
#           2.7910e+00, -3.4919e-01,  6.2006e-01,  9.6978e-01,  1.4420e+00,
#          -1.9783e-01, -1.0854e+00,  6.6120e-01,  9.3911e-01, -3.0966e-01,
#          -2.3593e-01,  1.0913e+00, -9.2944e-02,  3.0712e+00,  1.6341e+00,
#           6.1529e-01, -1.7199e+00, -6.3964e-01,  1.0634e+00,  1.4834e+00,
#           4.5884e-01,  1.4222e+00,  1.7285e+00,  6.4568e-01,  6.6756e-01,
#           9.8492e-01,  1.0526e+00,  9.1056e-01, -7.2316e-01,  1.7343e+00,
#           3.5313e-02,  2.2553e-02, -4.8388e-02,  6.6011e-01, -1.4665e+00],
#         [ 3.6807e-01,  8.7200e-01,  1.2668e-01, -3.0759e-01,  1.8436e+00,
#           1.3752e+00,  2.0361e-02,  1.4806e+00,  1.0259e+00,  1.2356e+00,
#           8.7894e-01,  1.3659e+00,  1.5255e+00,  4.0204e-01,  2.2426e+00,
#          -5.0158e-01, -3.0666e-01,  1.6617e+00,  6.3039e-01,  8.0189e-01,
#           7.4356e-01,  3.3300e-01, -4.5553e-01, -2.7140e-01,  6.8047e-01,
#           8.8394e-01,  3.3808e-01,  1.0283e+00,  2.6048e+00,  1.7394e-01,
#           1.7684e+00,  3.5267e-01,  1.9389e+00,  4.5775e-01, -3.0495e-01,
#          -3.6565e-01,  1.2873e+00,  1.4315e+00,  1.4175e+00, -1.7308e+00,
#          -1.4587e+00,  1.0188e+00,  5.5368e-01,  7.8835e-01,  1.1464e-01,
#           1.5761e-01, -1.3293e+00,  8.5072e-01, -7.2389e-01,  1.6919e-01],
#         [-8.3780e-01,  1.3837e+00,  9.6333e-02,  4.4311e+00,  3.5542e-01,
#          -1.2993e-01,  3.9727e-01, -8.2634e-01, -6.4056e-01, -1.5383e-01,
#          -4.7267e-02, -1.4518e-01, -5.1223e-02,  2.7838e-02,  2.5558e+00,
#           1.0548e+00,  5.8096e-01,  1.8372e+00,  1.9215e+00,  2.8307e-01,
#           2.6051e-01, -7.9901e-01,  3.5242e-01, -1.0754e+00,  1.7338e+00,
#           1.6415e+00,  1.9200e+00, -7.6424e-01,  3.5959e-01,  1.0336e+00,
#           2.4500e+00, -3.1224e-01, -4.9696e-02,  8.6204e-01, -2.3973e-01,
#          -1.3345e+00,  1.0574e+00,  8.5752e-01,  1.3107e+00,  1.8024e+00,
#           8.0786e-01,  7.0567e-01,  1.1054e+00, -1.7519e-01, -3.9703e-01,
#          -4.3852e-01, -1.1260e+00,  2.9102e+00,  3.5949e-03, -5.5312e-01]])

# %%
a = [1]*8

# %%
0.5*a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-cda87177ffa5> in <module>()
# ----> 1 0.5*a
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
torch.mul(x,y)
# Out:
# tensor([[-1.3426e+00,  1.1839e-01, -1.2218e+00, -2.2162e-01, -1.9100e-01,
#           1.2570e+00, -3.4034e-02, -1.2746e-01, -8.2249e-01, -8.3497e-01,
#          -4.0989e-01, -2.6595e-01, -3.9027e-01,  4.4154e-02,  1.0319e+00,
#          -7.3006e-03,  5.2942e-01, -8.0097e-03,  3.3872e-01,  2.9605e-01,
#          -1.1599e-01,  7.2672e-02, -3.3293e-01, -1.4528e-01,  7.9535e-01,
#          -2.3816e-01, -7.0218e-01, -7.1539e-01, -2.1532e-01, -4.5214e-01,
#           2.6242e-01,  1.0639e-01, -4.5165e-01, -7.9665e-01,  3.4077e-01,
#           2.2819e-01,  5.9807e-02, -4.3522e-01, -1.0333e-01, -6.6305e-01,
#           1.2011e+00,  8.8361e-01, -1.1895e-01,  8.2189e-02, -2.1766e-01,
#          -1.1039e+00, -1.2325e-01, -5.1053e-01,  2.3537e-01,  8.8695e-02],
#         [-1.2546e-01,  1.1666e-01,  4.7909e-01, -1.3894e+00, -6.3668e-03,
#           5.9588e-01,  9.1368e-01,  7.7995e-02,  3.0418e-01,  1.2657e-01,
#          -1.4624e-02, -2.8955e-01,  7.0085e-01, -2.3118e-01, -2.5329e-01,
#           7.4412e-01,  5.0046e-01,  3.9518e-01,  1.0550e-01,  1.5624e-01,
#           1.7754e-02,  8.3428e-02, -2.6641e-01, -3.2324e-02, -1.3485e-01,
#           1.9773e-02, -1.1339e-01, -2.9402e-02,  1.1274e+00, -7.4642e-02,
#           2.8704e-02,  6.2933e-01, -4.4472e-02,  9.3184e-02, -1.7501e-01,
#          -1.4992e-02,  1.9592e-01,  5.9981e-01,  2.9770e-01,  4.1170e-01,
#           4.0492e-01, -3.1714e-02,  1.3364e-01, -2.6095e-01, -1.8295e-01,
#           4.1058e-01, -2.7753e-01,  1.5822e-01, -1.3547e-01, -6.6807e-02],
#         [-1.6328e-01,  1.0181e-01,  5.2019e-01, -3.5447e-01, -4.4012e-01,
#           5.2592e-03, -2.7804e-01,  6.2830e-02,  9.0340e-01, -3.1572e-01,
#          -3.0954e-02,  2.5814e-01,  2.3092e-01, -4.1666e-01, -3.7592e-03,
#          -3.2947e-01,  3.4726e-01,  3.4385e-01, -3.1545e-01, -1.5003e-01,
#          -1.0495e+00, -1.5175e-01, -3.6942e-01,  5.7417e-02, -5.3247e-01,
#          -4.9234e-01,  1.2373e-01, -1.3688e-01, -8.9980e-01, -2.9837e-01,
#          -5.5204e-02, -4.4208e-01,  6.7884e-02,  2.8872e-01,  1.2133e-01,
#           6.9765e-02,  6.0827e-01, -3.2332e-01, -1.6482e-01,  3.2132e-01,
#           1.1473e+00,  5.9485e-03, -2.0721e-01,  4.9381e-01, -2.1895e-02,
#           4.7140e-03, -5.6516e-01, -3.7422e-02, -1.5437e+00, -3.2815e-01],
#         [ 1.2719e-01, -3.9064e-01, -3.2194e-01,  7.7337e-02,  7.5782e-01,
#          -9.3116e-01, -4.0279e-02,  6.3711e-01,  1.1222e-01,  4.5667e-01,
#           4.0627e-01,  1.5202e-02,  1.5636e+00,  1.0784e-01,  2.2615e-01,
#          -5.4231e-01, -1.3212e+00,  2.8117e-01, -6.2719e-01, -9.4535e-02,
#           7.6752e-02,  7.6824e-01,  1.5110e-01,  1.0744e-01, -5.3687e-02,
#          -2.0347e-02, -1.2643e-01,  6.6553e-01, -3.8719e-01, -1.0423e-01,
#          -7.8334e-01, -7.3984e-01,  7.3945e-01, -1.2110e+00,  5.5728e-01,
#           3.3409e-01, -1.5072e-01, -7.7249e-02, -1.3340e-01, -3.0589e-01,
#           2.0416e-01, -7.3170e-02, -5.5765e-02,  5.7459e-01,  7.0089e-01,
#           2.7758e-01,  1.5405e-02,  3.0017e-01, -1.3978e-02, -1.8795e-02],
#         [-7.0554e-01, -9.6941e-02,  6.4067e-02, -6.5420e-02,  2.5132e-01,
#           1.0255e-01, -1.1964e+00, -6.9267e-02,  5.3016e-02, -1.1906e-01,
#           3.4073e-02,  5.9291e-01,  5.9650e-01,  1.1313e+00, -4.3952e-02,
#           9.5770e-02,  1.0781e-01, -4.4600e-01, -1.5287e+00, -1.5203e-01,
#           9.4023e-02,  3.5198e-01,  2.6800e-01, -4.0317e-01,  2.1741e+00,
#           2.7877e-01,  8.2745e-01, -2.7793e-01, -3.0188e-01, -3.5376e-02,
#           5.9164e-04, -2.6930e-01, -1.4560e-01,  6.8173e-01,  7.0045e-01,
#           3.5572e-01, -8.8272e-01, -6.0184e-02,  3.0387e-01, -2.6847e-01,
#           1.2136e-01,  6.0030e-03,  4.1424e-01, -3.1686e-01,  8.0361e-01,
#          -1.6287e-02, -1.0613e+00,  1.3413e-01, -5.4006e-02,  1.1254e-01],
#         [-1.4104e+00, -6.4414e-02, -4.1395e-01, -2.1792e-01,  1.4168e-01,
#           5.7330e-01,  4.4399e-01, -9.6406e-01, -1.9631e-01, -2.7398e-01,
#          -2.8904e-01, -5.9689e-01, -1.6606e-02,  1.4755e-01,  5.9393e-01,
#           7.1788e-01,  3.3916e-01, -6.9806e-03,  5.4230e-01,  1.3358e-02,
#           4.2745e-02, -2.9619e-02,  3.2661e-02,  1.8071e-01,  5.1542e-01,
#           5.5606e-01,  4.2732e-01,  9.5614e-02,  8.4580e-01, -9.1537e-01,
#           2.0031e-01, -1.6083e-01,  1.1459e+00,  6.1278e-01, -1.7119e-01,
#          -5.0628e-02, -6.2949e-01,  2.5240e-02, -6.8128e-02, -3.6086e-01,
#          -3.3600e-02,  2.6981e-01, -9.0237e-02, -2.3255e-01, -4.0237e-01,
#          -1.0447e-01,  6.8957e-01, -1.0078e+00,  8.2972e-01, -6.3100e-02],
#         [ 2.9119e-01,  8.4502e-01, -8.9449e-01, -2.5334e-02,  1.8464e+00,
#          -4.1042e-03, -1.4223e-01, -1.2516e-01, -2.7897e-02,  8.5111e-02,
#           3.7717e-01,  3.5924e-01, -1.0497e-01,  2.5205e-01, -5.6140e-01,
#           1.1171e-01,  4.2352e-01, -1.5176e-01, -1.6396e-02,  1.0387e-01,
#           1.6464e-01,  5.9833e-01, -1.4029e+00,  1.4834e-01,  2.1090e-02,
#          -1.4178e-01,  1.6906e-01, -5.1478e-01, -7.0348e-01, -9.4187e-02,
#           3.4527e-02, -1.0572e+00, -1.3208e-02,  6.4886e-01,  7.8593e-01,
#          -7.8933e-02,  5.8944e-01, -3.4300e-02, -5.4733e-01, -3.3406e-02,
#           3.5217e-01,  1.2372e+00,  9.7727e-01,  1.3880e+00,  3.2416e-02,
#           1.3480e-01, -2.3130e-01, -2.1500e-01, -5.8144e-02, -1.1124e-01],
#         [-9.5679e-01, -6.3097e-01,  1.2816e-02,  8.6294e-03, -4.5369e-01,
#           7.2158e-01,  5.4150e-01, -2.7680e-01,  5.7275e-01, -8.4584e-02,
#          -1.7934e-02,  9.3108e-02,  5.8542e-01,  1.9527e-02,  2.3906e-01,
#          -4.2739e-01, -3.6944e-01,  4.4783e-02, -8.7665e-01, -3.3667e-01,
#          -7.4538e-02, -8.6097e-01, -2.0329e-01,  4.3097e-01,  7.2956e-02,
#           7.5461e-01,  4.4955e-01,  9.2428e-01,  4.3351e-02,  5.7622e-01,
#          -1.1960e+00,  6.3334e-01,  2.2348e-01, -3.7173e-01, -1.9202e-01,
#           5.3803e-01, -4.7377e-01,  1.9265e-01,  4.8879e-01, -3.7292e-01,
#           4.9099e-02, -9.5457e-02, -7.8768e-02,  1.5061e-01, -5.9539e-02,
#          -3.0302e-02,  2.1874e-01, -2.2145e-01,  1.5925e-02,  1.1651e-01],
#         [-4.7107e-02,  4.6129e-01,  3.7361e-02,  2.5673e-01,  1.4739e+00,
#           5.7456e-01, -1.3903e-01,  1.3561e-01, -2.5657e-01, -5.4146e-01,
#          -5.6401e-01, -9.1865e-01, -1.2660e+00,  4.9987e-01,  2.9565e-01,
#           3.9281e-01,  2.3832e-01,  8.5726e-01,  1.1675e-02,  5.3979e-01,
#          -2.9005e-02,  4.7672e-02, -5.2383e-04,  2.0249e-01, -1.4928e-02,
#          -9.8318e-02,  1.2119e-01,  1.2338e+00, -2.2990e-01, -4.1579e-01,
#          -1.0552e+00, -5.4195e-01,  4.0606e-01,  1.8061e-02,  7.0512e-04,
#          -2.3668e-02,  1.7204e-01,  2.1144e-02, -2.8925e-01,  8.1227e-02,
#          -6.8396e-01,  2.6895e-01, -1.4748e-02, -1.1748e-01, -3.9627e-01,
#          -7.8150e-01, -1.3334e+00,  1.1301e-01, -5.7656e-01, -1.1116e+00],
#         [-1.2477e-01, -2.0012e-01,  1.3684e-01, -1.2924e-01,  5.7213e-01,
#           2.8027e-01,  1.4864e-01,  1.3285e+00, -2.1003e-02,  6.3827e-02,
#          -9.1576e-01, -8.0491e-02, -4.5076e-01,  7.3193e-02,  5.9500e-02,
#          -5.6848e-02,  9.8123e-01, -1.5122e-02,  1.0284e+00, -9.7001e-02,
#          -8.3935e-01, -2.1916e-01, -7.3088e-01, -1.8296e-01,  1.8822e+00,
#          -3.0859e-01, -7.3549e-01, -1.4690e-01, -1.0192e-02, -1.8728e-01,
#           2.1381e-03,  1.4020e-01,  2.5341e-01, -7.1443e-03, -4.3737e-01,
#           5.7212e-03,  7.3252e-01,  7.4574e-01, -8.8645e-02, -7.4532e-01,
#          -7.4200e-02, -1.2233e+00,  2.1957e-01, -6.7966e-02,  8.5518e-02,
#          -5.5419e-03,  1.6812e-01, -4.6859e-01, -1.8251e-01,  2.1881e+00],
#         [-7.8223e-01,  9.8834e-01,  5.8102e-01, -1.8858e+00,  5.4699e-01,
#          -1.0609e+00,  2.1321e-01, -4.0314e-01,  2.6473e-01, -1.8335e-01,
#          -3.1172e-01, -3.4083e-01,  8.5306e-01,  7.0507e-02,  2.4243e-01,
#           4.4259e-02,  5.1992e-01,  2.0515e+00, -6.8602e-01, -2.2331e+00,
#          -2.7957e-02,  3.3952e-01,  5.6041e-02,  6.2804e-02,  3.1183e-01,
#           6.2438e-01,  2.4579e-02,  9.7418e-02, -3.1952e-01,  2.2664e+00,
#           1.9614e+00, -2.8909e-02, -2.6400e-01, -1.7448e-01,  1.1442e-01,
#          -4.3854e-01,  1.0236e-01, -6.5226e-01, -1.7673e-01, -8.1961e-01,
#          -1.7073e+00,  2.1567e-01, -8.4825e-02,  2.6000e-01, -9.0779e-02,
#           2.1875e-01,  4.2775e-01,  3.1888e-02, -1.5003e-01,  6.1044e-01],
#         [ 1.2976e+00, -7.1603e-02,  1.0591e+00, -1.1746e+00,  7.8000e-01,
#           2.1219e-01, -3.3026e-01, -5.1353e-01,  2.6873e-02, -2.3579e-01,
#          -9.1447e-02, -4.7023e-01, -1.0932e-02,  9.8449e-01, -3.5834e-01,
#           1.4799e-01,  1.0641e+00,  8.3503e-01,  7.6221e-01, -3.3811e-01,
#           7.9745e-01, -1.4779e-01, -2.2731e-01, -8.4043e-01,  8.7284e-03,
#           7.1938e-01,  1.0279e+00, -1.2279e+00, -1.3066e-01, -5.3023e-01,
#          -9.7615e-01, -3.1876e-01,  1.0992e-01,  5.8723e-01,  2.4713e-01,
#           6.1908e-01, -2.0153e-03,  2.2298e-01,  1.9669e-01,  1.2323e-01,
#          -1.0048e-01, -3.3586e-02,  3.1841e-01, -2.5978e-01,  9.2116e-02,
#           4.5054e-02, -3.0751e-01, -4.9372e-01, -2.2993e-01, -9.9165e-01],
#         [ 1.0958e-01,  2.9786e-04, -7.6285e-01,  1.3533e-01, -5.0139e-01,
#           1.7808e+00, -1.0092e-01, -2.3601e-01, -8.5615e-02, -1.0856e-01,
#          -1.9901e-02, -6.4726e-01,  7.9505e-01, -7.3000e-01, -8.1443e-01,
#          -1.5709e-01, -5.4763e-01, -8.2410e-01,  1.2000e-01, -3.3240e-01,
#          -9.7991e-01, -1.6211e-02, -1.2321e-01, -5.3933e-02,  9.5950e-03,
#           6.8323e-01, -4.7888e-02,  2.2826e-01, -2.3423e-01,  9.7912e-02,
#          -1.0578e+00,  6.0345e-03,  2.9310e-01, -9.1178e-01, -1.3236e-01,
#          -5.1161e-01,  1.5267e-02, -8.6494e-01, -5.1696e-01, -6.9670e-01,
#          -3.6779e-01, -3.4197e-01, -6.4278e-02,  1.7020e-01, -6.8489e-01,
#           3.5286e-01, -4.0367e-02, -1.3271e-01, -2.3789e-01,  4.6834e-01],
#         [-5.4110e-02, -5.0074e-04, -1.0544e-02, -6.6780e-01, -2.4452e-01,
#           6.7958e-01, -6.9763e-01, -1.9717e-02, -3.8787e-01,  1.7678e-01,
#          -1.2839e-02, -5.5490e-01,  4.9115e-01, -1.1155e+00, -2.1940e-03,
#          -1.0384e-01,  1.0943e-01,  3.4592e-01,  1.9731e-01,  1.5128e+00,
#           1.2134e+00,  1.0090e-01, -8.8309e-01,  4.8317e-02,  1.7119e-01,
#           5.5745e-01,  1.0610e+00,  1.5216e+00,  4.9336e-01,  8.3822e-02,
#          -6.3914e-03, -1.0675e-01,  1.2257e-02, -2.6343e-01, -8.6862e-01,
#          -3.0660e-01,  4.6749e-02, -6.5700e-01, -2.0542e-01,  5.9792e-01,
#           4.4658e-03,  1.3291e-02, -9.9971e-02,  7.2275e-01, -6.6525e-01,
#          -1.2802e+00, -1.0455e-01,  3.5819e-02,  2.9488e-01, -3.1062e-01],
#         [ 6.2355e-01,  2.6246e-02,  3.4957e-01,  1.8449e+00,  3.0231e-01,
#          -3.1594e-01, -8.0338e-01,  3.5309e-01, -3.7274e-01, -1.3443e+00,
#          -1.7388e+00,  6.6506e-01,  4.8639e-01,  8.2939e-02, -1.2365e-02,
#           6.6917e-01,  2.4549e-01, -1.9256e-01,  5.5008e-02,  3.9155e-01,
#           2.7643e-01, -1.2073e-01,  5.0291e-01, -9.6942e-01,  6.2754e-02,
#          -1.6497e+00,  6.0309e-03,  4.5769e-01,  9.0484e-03, -4.8518e-02,
#           1.3640e+00, -1.1873e-01,  6.0888e-03,  2.2901e-01, -5.5809e-01,
#           4.5894e-02, -1.0604e-01,  5.1404e-03,  4.2445e-01, -7.7323e-01,
#          -1.3115e-02,  2.4167e-01,  2.7039e-02,  1.5602e-01, -1.2040e-01,
#          -7.4002e-01, -8.2559e-02,  8.3509e-01,  3.1913e-02, -2.1610e-01],
#         [ 5.1479e-01, -1.3977e+00, -4.3801e-01, -3.3895e-01,  2.1784e-01,
#           9.5343e-01, -1.7077e-01, -7.8760e-02,  3.0446e-02, -3.7052e-01,
#          -7.5208e-01,  9.5233e-02, -9.2483e-02, -4.1483e-01, -1.8591e-02,
#           1.0581e-01, -6.0168e-01, -8.1487e-03,  1.4241e-01, -2.0690e-01,
#           2.1194e-01,  7.2935e-01,  3.8055e-01, -3.0475e-01, -3.3984e-04,
#           3.1389e-01, -4.5217e-01, -1.5619e-04,  1.4999e-01,  2.4112e-02,
#          -2.3630e-01,  3.5700e-01, -9.7245e-01,  7.9308e-02,  7.2034e-01,
#          -4.1833e-01,  3.7201e-01,  8.9956e-01, -9.2487e-02, -1.0991e+00,
#           1.1951e+00,  6.8962e-01, -1.2238e+00, -1.1767e-02, -3.1791e-01,
#          -2.3337e-01,  1.1328e+00, -1.0336e+00, -7.1804e-01, -4.2926e-03]])

# %%
x = x.to(device)

# %%
x = x.data
x = x.cpu()
x = x.numpy()

# %%
str(x)
# Out:
# '24'

# %%
z = torch.cat((x, x), 0)

# %%
z.shape
# Out:
# torch.Size([1536, 1])

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from random import randrange
import torch.nn.functional as F
import pandas as pd

# %%
text =statements['train'][2]

# %%
len(text.split(' '))
# Out:
# 19

# %%
zz = tokenizer.tokenize(text)

# %%
len(zz)
# Out:
# 22

# %%
train_path = '/home/ubuntu/fake_news/LIAR-PLUS/dataset/train2.tsv'
test_path = '/home/ubuntu/fake_news/LIAR-PLUS/dataset/test2.tsv'
val_path = '/home/ubuntu/fake_news/LIAR-PLUS/dataset/val2.tsv'

# %%
train_df = pd.read_csv(train_path, sep="\t", header=None)
test_df = pd.read_csv(test_path, sep="\t", header=None)
val_df = pd.read_csv(val_path, sep="\t", header=None)

# Fill nan (empty boxes) with 0
train_df = train_df.fillna('None')
test_df = test_df.fillna('None')
val_df = val_df.fillna('None')

# %%
train = train_df.values
test = test_df.values
val = val_df.values

# %%
labels = {'train':[train[i][2] for i in range(len(train))], 'test':[test[i][2] for i in range(len(test))], 'val':[val[i][2] for i in range(len(val))]}
statements = {'train':[train[i][3] for i in range(len(train))], 'test':[test[i][3] for i in range(len(test))], 'val':[val[i][3] for i in range(len(val))]}
subjects = {'train':[train[i][4] for i in range(len(train))], 'test':[test[i][4] for i in range(len(test))], 'val':[val[i][4] for i in range(len(val))]}
speakers = {'train':[train[i][5] for i in range(len(train))], 'test':[test[i][5] for i in range(len(test))], 'val':[val[i][5] for i in range(len(val))]}
jobs = {'train':[train[i][6] for i in range(len(train))], 'test':[test[i][6] for i in range(len(test))], 'val':[val[i][6] for i in range(len(val))]}
states = {'train':[train[i][7] for i in range(len(train))], 'test':[test[i][7] for i in range(len(test))], 'val':[val[i][7] for i in range(len(val))]}
affiliations = {'train':[train[i][8] for i in range(len(train))], 'test':[test[i][8] for i in range(len(test))], 'val':[val[i][8] for i in range(len(val))]}
credits = {'train':[train[i][9:14] for i in range(len(train))], 'test':[test[i][9:14] for i in range(len(test))], 'val':[val[i][9:14] for i in range(len(val))]}
contexts = {'train':[train[i][14] for i in range(len(train))], 'test':[test[i][14] for i in range(len(test))], 'val':[val[i][14] for i in range(len(val))]}
justification = {'train':[train[i][15] for i in range(len(train))], 'test':[test[i][15] for i in range(len(test))], 'val':[val[i][15] for i in range(len(val))]}

# %%
ma = 256
p = 0
for i in range(len(train)):
    #print(justification['val'][i])
    if len(justification['train'][i].split(' ')) > ma:
    
        print(len(justification['train'][i].split(' ')))
        p = p+1
# Out:
# 842
# 508
# 662
# 289
# 3030
# 3025
# 709
# 1974
# 2966
# 821
# 708
# 271
# 544
# 260
# 1094
# 273
# 258
# 268
# 370
# 452
# 260
# 276
# 318
# 491

# %%
p
# Out:
# 24

# %%
speaker['train']
# Out:
# ['dwayne-bohac',
#  'scott-surovell',
#  'barack-obama',
#  'blog-posting',
#  'charlie-crist',
#  'robin-vos',
#  'republican-party-texas',
#  'barack-obama',
#  'oregon-lottery',
#  'duey-stroebel',
#  'robert-menendez',
#  'bernie-s',
#  'mitt-romney',
#  'doonesbury',
#  'george-will',
#  'bernie-s',
#  'barack-obama',
#  'national-republican-congressional-committee',
#  'gwen-moore',
#  'jack-lew',
#  'dennis-richardson',
#  'eric-bolling',
#  'hillary-clinton',
#  'greater-wisconsin-political-fund',
#  'planned-parenthood-action-fund',
#  'nancy-pelosi',
#  'hillary-clinton',
#  'ted-nugent',
#  'pamela-geller',
#  'peter-kinder',
#  'hillary-clinton',
#  'nicholas-kettle',
#  'shelley-moore-capito',
#  'rick-scott',
#  'tom-cotton',
#  'ted-cruz',
#  'lee-leffingwell',
#  'north-korea',
#  'walking-dead',
#  'kelly-ayotte',
#  'marco-rubio',
#  'keep-promise-1-pac',
#  'national-republican-congressional-committee',
#  'rachel-maddow',
#  'jerry-patterson',
#  'bernie-s',
#  'chain-email',
#  'john-boehner',
#  'katrina-pierson',
#  'blog-posting',
#  'rick-perry',
#  'national-republican-senatorial-committee',
#  'ken-cuccinelli',
#  'andrew-cuomo',
#  'sid-miller',
#  'jim-barksdale',
#  'david-raynor',
#  'donald-trump',
#  'john-mccain',
#  'battleground-texas',
#  'michelle-obama',
#  'rudy-giuliani',
#  'john-barrasso',
#  'empower-texans',
#  'john-depetro',
#  'garnet-coleman',
#  'mitt-romney',
#  'donald-trump',
#  'michael-opitz',
#  'rick-scott',
#  'terry-mcauliffe',
#  'mitt-romney',
#  'alfredo-gutierrez',
#  'david-cote',
#  'barack-obama',
#  'george-will',
#  'elena-kagan',
#  'texas-veterans-commission',
#  'republican-party-florida',
#  'maurice-ferre',
#  'jeanne-shaheen',
#  'susan-happ',
#  'sameh-shoukry',
#  'karl-rove',
#  'gwen-graham',
#  'bill-white',
#  'bob-goodlatte',
#  'cory-booker',
#  'joe-biden',
#  'jim-skaggs',
#  'john-mccain',
#  'rick-perry',
#  'ralph-hudgens',
#  'mitt-romney',
#  'mitt-romney',
#  'florida-democratic-party',
#  'robert-sarvis',
#  'will-weatherford',
#  'mark-shields',
#  'national-association-realtors',
#  'brady-campaign-prevent-gun-violence',
#  'federal-transit-administration',
#  'alison-lundergan-grimes',
#  'mitch-mcconnell',
#  'donald-trump',
#  'barack-obama',
#  'frank-caprio',
#  'rick-perry',
#  'david-scott',
#  'terry-mcauliffe',
#  'scott-walker',
#  'ron-johnson',
#  'donna-brazile',
#  'paul-ryan',
#  'barack-obama',
#  'adam-hasner',
#  'mark-pocan',
#  'blog-posting',
#  'joe-biden',
#  'ted-cruz',
#  'hillary-clinton',
#  'kathleen-sebelius',
#  'bruce-elfant',
#  'republican-party-florida',
#  'dave-yost',
#  'alex-sink',
#  'hillary-clinton',
#  'blog-posting',
#  'government-not-god-pac',
#  'joe-scarborough',
#  'texas-house-democratic-caucus',
#  'john-mccain',
#  'marco-rubio',
#  'rick-scott',
#  'david-jolly',
#  'jon-keyser',
#  'oregon-right-life-pac',
#  'sean-hannity',
#  'rush-limbaugh',
#  'mitt-romney',
#  'john-robitaille',
#  'patricia-morgan',
#  'dave-brat',
#  'hillary-clinton',
#  'mark-warner',
#  'barack-obama',
#  'rob-portman',
#  'john-cornyn',
#  'louie-gohmert',
#  'donald-trump',
#  'mitt-romney',
#  'democratic-congressional-campaign-committee',
#  'texas-right-life',
#  'armond-budish',
#  'jeff-kruse',
#  'mike-haridopolos',
#  'kendrick-meek',
#  'americans-united-change',
#  'paul-skip-stam',
#  'bernie-s',
#  'eric-cantor',
#  'paul-ryan',
#  'chain-email',
#  'robert-puente',
#  'marco-rubio',
#  'ron-paul',
#  'blog-posting',
#  'nancy-pfotenhauer',
#  'gary-johnson',
#  'stephen-sweeney',
#  'sheldon-whitehouse',
#  'pat-quinn',
#  'matthew-dowd',
#  'rudy-giuliani',
#  'one-new-jersey',
#  'darrell-issa',
#  'robert-gibbs',
#  'michael-williams',
#  'alan-grayson',
#  'chris-christie',
#  'robert-jacquard',
#  'eric-cantor',
#  'americas-health-insurance-plans',
#  'dream-defenders',
#  'greg-abbott',
#  'david-cicilline',
#  'wendy-davis',
#  'marcy-kaptur',
#  'americans-tax-reform',
#  'tweets',
#  'tamara-holder',
#  'hank-johnson',
#  'chain-email',
#  'facebook-posts',
#  'mike-murphy',
#  'hillary-clinton',
#  'sean-hannity',
#  'bernie-s',
#  'bernie-s',
#  'ted-cruz',
#  'vincent-barrella',
#  'alan-grayson',
#  'lamar-smith',
#  'bill-johnson',
#  'eric-hovde',
#  'john-skvarla',
#  'daniel-mielke',
#  'florida-democratic-party',
#  'ben-carson',
#  'blue-oregon',
#  'raymond-bateman',
#  'mark-neumann',
#  'sarah-palin',
#  'rana-foroohar',
#  'barack-obama',
#  'alan-grayson',
#  'tom-niehaus',
#  'sherrod-brown',
#  'nextgen-climate',
#  'john-kasich',
#  'barack-obama',
#  'mitch-mcconnell',
#  'ileana-ros-lehtinen',
#  'chris-moews',
#  'robby-mook',
#  'carolyn-maloney',
#  'lindsey-graham',
#  'mark-strama',
#  'joe-biden',
#  'patrick-leahy',
#  'fix-austin-schools',
#  'democratic-senatorial-campaign-committee',
#  'agenda-project',
#  'steven-teske',
#  'hank-johnson',
#  'rand-paul',
#  'dave-brat',
#  'national-republican-senatorial-committee',
#  'kesha-rogers',
#  'sheldon-whitehouse',
#  'james-bennett',
#  'rick-perry',
#  'tom-hughes',
#  'jeff-merkley',
#  'barack-obama',
#  'sheila-oliver',
#  'judd-gregg',
#  'donald-trump',
#  'hillary-clinton',
#  'dick-cheney',
#  'national-republican-senatorial-committee',
#  'michael-moore',
#  'hillary-clinton',
#  'bill-richardson',
#  'barack-obama',
#  'paul-sarlo',
#  'barack-obama',
#  'connie-mack',
#  'facebook-posts',
#  'rick-scott',
#  'rush-limbaugh',
#  'allen-west',
#  'evan-feinberg',
#  'bill-white',
#  'facebook-posts',
#  'moveon',
#  'ken-cuccinelli',
#  'donald-trump',
#  'gwen-moore',
#  'rudy-giuliani',
#  'lou-dobbs',
#  'edith-ajello',
#  'john-mccain',
#  'doug-thomas',
#  'steve-latourette',
#  'trent-franks',
#  'scott-walker',
#  'kim-guadagno',
#  'marco-rubio',
#  'rick-scott',
#  'scott-walker',
#  'ted-strickland',
#  'thomas-brown',
#  'moveon',
#  'us-chamber-commerce',
#  'scott-brown',
#  'marco-rubio',
#  'julian-castro',
#  'christine-sinicki',
#  'sheldon-whitehouse',
#  'chain-email',
#  'barack-obama',
#  'rick-perry',
#  'rob-portman',
#  'michele-bachmann',
#  'rudy-giuliani',
#  'dan-patrick',
#  'barack-obama',
#  'jeb-bush',
#  'florida-chamber-commerce',
#  'rick-perry',
#  'jerry-patterson',
#  'rachel-campos-duffy',
#  'newt-gingrich',
#  'ron-paul',
#  'tom-barrett',
#  'roy-blunt',
#  'chris-thomas',
#  'lindsey-graham',
#  'barney-simms',
#  'chain-email',
#  'national-republican-congressional-committee',
#  'rush-limbaugh',
#  'andrew-napolitano',
#  'marco-rubio',
#  'marco-rubio',
#  'joyce-kaufman',
#  'christopher-plante',
#  'gerry-connolly',
#  'dave-weldon',
#  'jeb-bush',
#  'rachel-maddow',
#  'george-will',
#  'john-garamendi',
#  'donna-edwards',
#  'peter-kilmartin',
#  'roger-williams',
#  'republican-party-florida',
#  'marco-rubio',
#  'david-dewhurst',
#  'joshua-feuerstein',
#  'bill-belichick',
#  'ted-cruz',
#  'associated-press',
#  'joe-biden',
#  'josh-mandel',
#  'nathan-deal',
#  'barack-obama',
#  'rick-perry',
#  'bill-clinton',
#  'john-boehner',
#  'barack-obama',
#  'chip-rogers',
#  'alan-grayson',
#  'julius-jones',
#  'mike-huckabee',
#  'john-kasich',
#  'national-association-manufacturers',
#  'barack-obama',
#  'chris-hayes',
#  'barack-obama',
#  'bernie-s',
#  'rick-perry',
#  'progress-texas',
#  'ben-carson',
#  'bill-white',
#  'dinesh-dsouza',
#  'joe-biden',
#  'bernie-s',
#  'bill-foster',
#  'rachel-maddow',
#  'ken-legler',
#  'milwaukee-police-association',
#  'clackamas-county-commission',
#  'scott-henson',
#  'bob-mcdonnell',
#  'don-francis',
#  'dwight-jones',
#  'organizing-america',
#  'rick-santorum',
#  'chris-wallace',
#  'save-americas-postal-service',
#  'lloyd-doggett',
#  'rob-cornilles',
#  'frank-guinta',
#  'facebook-posts',
#  'cory-mason',
#  'dan-kaufman',
#  'donald-trump',
#  'larry-elder',
#  'dale-kooyenga',
#  'terry-mcauliffe',
#  'barack-obama',
#  'dan-gelber',
#  'new-hampshire-democratic-party',
#  'mary-nolan',
#  'jim-steineke',
#  'michelle-rhee',
#  'joe-gibbons',
#  'steve-rothman',
#  'mary-margaret-oliver',
#  'wendy-davis',
#  'mark-warner',
#  'drug-free-america',
#  'chain-email',
#  'david-cicilline',
#  'chuck-grassley',
#  'ted-wheeler',
#  'herb-garrett',
#  'vincent-buddy-cianci',
#  'mike-huckabee',
#  'direct-action-rights-equality',
#  'peter-shumlin',
#  'mike-huckabee',
#  'chris-christie',
#  'national-organization-marriage',
#  'rudy-giuliani',
#  'rick-santorum',
#  'jon-stewart',
#  'charlie-crist',
#  'americans-prosperity',
#  'karen-handel',
#  'barack-obama',
#  'adam-kinzinger',
#  'barack-obama',
#  'donna-howard',
#  'GaGOP',
#  'bob-graham',
#  'john-bradley',
#  'glenn-grothman',
#  'we-are-ohio',
#  'arianna-huffington',
#  'chain-email',
#  'joe-lieberman',
#  'jon-erpenbach',
#  'john-kerry',
#  'rudy-giuliani',
#  'lou-greenwald',
#  'kathleen-vinehout',
#  'david-dewhurst',
#  'john-boehner',
#  'michele-bachmann',
#  'michael-burgess',
#  'joe-scarborough',
#  'republican-governors-association',
#  'ralph-nader',
#  'leticia-van-de-putte',
#  'david-scott',
#  'craig-melvin',
#  'barack-obama',
#  'john-plumb',
#  'judicial-watch',
#  'tom-price',
#  'blog-posting',
#  'donald-trump',
#  'sondy-pope',
#  'rick-perry',
#  'gwen-moore',
#  'george-will',
#  'jon-stewart',
#  'carlos-curbelo',
#  'democratic-congressional-leadership',
#  'jeb-bush',
#  'barack-obama',
#  'claudia-tenney',
#  'no-60-campaign-against-condom-requirement-adult-fi',
#  'loretta-weinberg',
#  'americans-united-change',
#  'todd-hunter',
#  'tim-knopp',
#  'rick-perry',
#  'sandy-adams',
#  'brett-hulsey',
#  'barack-obama',
#  'james-clyburn',
#  'hillary-clinton',
#  'mike-haridopolos',
#  'barack-obama',
#  'alex-sink',
#  'reince-priebus',
#  'donald-trump',
#  'bernie-s',
#  'john-boehner',
#  'victoria-taft',
#  'bernie-s',
#  'joe-biden',
#  'rahm-emanuel',
#  'frank-annunziato',
#  'democratic-congressional-campaign-committee',
#  'michael-steele',
#  'dennis-richardson',
#  'claire-mccaskill',
#  'joseph-crowley',
#  'mitt-romney',
#  '60-plus-association',
#  'chris-abele',
#  'kenneth-block',
#  'michael-doherty',
#  'chris-christie',
#  'ellen-rosenblum',
#  'john-kline',
#  'american-crossroads',
#  'tim-kaine',
#  'debbie-wasserman-schultz',
#  'michele-bachmann',
#  'tom-daschle',
#  'sarah-palin',
#  'jeff-morales',
#  'virginia-education-association',
#  'hank-johnson',
#  'causa-oregon',
#  'terry-jeffrey',
#  'glenn-grothman',
#  'republican-party-texas',
#  'jimmy-carter',
#  'jeff-dickerson',
#  'oregon-2014',
#  'thomas-tobin',
#  'bobby-jindal',
#  'chris-jacobs',
#  'phil-kerpen',
#  'joanne-kloppenburg',
#  'paul-ryan',
#  'debbie-wasserman-schultz',
#  'donald-trump',
#  'dinesh-dsouza',
#  'paul-krugman',
#  'mike-pence',
#  'scott-walker',
#  'bookerfail',
#  'debbie-wasserman-schultz',
#  'rob-portman',
#  'kay-bailey-hutchison',
#  'american-crossroads',
#  'democratic-national-committee',
#  'mike-foley',
#  'americans-job-security',
#  'rob-zerban',
#  'alan-grayson',
#  'jackie-cilley',
#  'barack-obama',
#  'national-republican-congressional-committee',
#  'arsalan-iftikhar',
#  'frank-guinta',
#  'rudy-giuliani',
#  'marc-schare',
#  'newt-gingrich',
#  'sandra-williams',
#  'john-kitzhaber',
#  'wendy-davis',
#  'hillary-clinton',
#  'barack-obama',
#  'hillary-clinton',
#  'rick-scott',
#  'katie-mcginty',
#  'rand-paul',
#  'mitt-romney',
#  'adam-putnam',
#  'virginia-foxx',
#  'clay-pell',
#  'hillary-clinton',
#  'barack-obama',
#  'ginny-brown-waite',
#  'chain-email',
#  'bill-proctor',
#  'kevin-dewine',
#  'naral-pro-choice',
#  'john-pagliarini',
#  'erik-wallin',
#  'kasim-reed',
#  'hillary-clinton',
#  'diego-arene-morley',
#  'donald-trump',
#  'rob-portman',
#  'richard-codey',
#  'alberta-darling',
#  'cory-gardner',
#  'marco-rubio',
#  'delia-garza',
#  'barack-obama',
#  'priorities-usa-action',
#  'ed-gillespie',
#  'john-kasich',
#  'tommy-thompson',
#  'mike-lee',
#  'david-axelrod',
#  'paul-broun',
#  'national-rifle-association',
#  'joe-biden',
#  'mitch-mcconnell',
#  'paul-ryan',
#  'martin-omalley',
#  'marco-rubio',
#  'barack-obama',
#  'sarah-palin',
#  'barack-obama',
#  'matthew-hill',
#  'rick-santorum',
#  'american-leadhership-pac',
#  'maurice-ferre',
#  'barack-obama',
#  'lisa-boothe',
#  'blog-posting',
#  'daniel-grace',
#  'charlie-crist',
#  'jeff-greene',
#  'jamie-radtke',
#  'scott-walker',
#  'sylvester-turner',
#  'rick-scott',
#  'chris-redfern',
#  'david-jolly',
#  'harris-faulkner',
#  'moveon',
#  'rob-cornilles',
#  'charles-schumer',
#  'kathleen-falk',
#  'tommy-thompson',
#  'steve-lonegan',
#  'next-generation-climate-action-committee',
#  'florida-chamber-commerce',
#  'rachel-maddow',
#  'barack-obama',
#  'corey-lewandowski',
#  'bobby-scott',
#  'dave-weldon',
#  'anissa-naouai',
#  'sean-duffy',
#  'donald-trump',
#  'nancy-pelosi',
#  'matthew-charles-cardinale',
#  'karl-rove',
#  'nathan-deal',
#  'chris-christie',
#  'angel-taveras',
#  'mike-rogers',
#  'sarah-palin',
#  'chris-hani-baragwanath-hospital',
#  'david-cicilline',
#  'bill-nelson',
#  'lincoln-chafee',
#  'kathleen-clyde',
#  'john-cornyn',
#  'richard-ferruccio',
#  'terry-lawler',
#  'blog-posting',
#  'ray-mcberry',
#  'centre-research-globalization',
#  'gene-sperling',
#  'kathleen-falk',
#  'cokie-roberts',
#  'barbara-boxer',
#  'republican-national-committee-republican',
#  'hillary-clinton',
#  'barack-obama',
#  'lincoln-chafee',
#  'ron-johnson',
#  'randy-forbes',
#  'club-growth',
#  'joaquin-castro',
#  'rick-scott',
#  'joe-manchin',
#  'markos-moulitsas',
#  'newt-gingrich',
#  'fulton-county-health-and-wellness',
#  'brigid-shea',
#  'chain-email',
#  'barack-obama',
#  'carly-fiorina',
#  'kesha-rogers',
#  'ron-paul',
#  'ken-allen',
#  'cory-booker',
#  'rick-perry',
#  'greg-abbott',
#  'barack-obama',
#  'neera-tanden',
#  'chuck-todd',
#  'bernie-s',
#  'barack-obama',
#  'debbie-wasserman-schultz',
#  'arthur-cyr',
#  'elaine-boyer',
#  'betty-sutton',
#  'keith-olbermann',
#  'jason-isaac',
#  'jennette-gayer',
#  'bill-hammond',
#  'health-care-america-now',
#  'paul-ryan',
#  'priorities-usa-action',
#  'glenn-grothman',
#  'marco-rubio',
#  'miscellany-blue',
#  'jim-renacci',
#  'sarah-palin',
#  'committee-our-childrens-future',
#  'tobias-read',
#  'john-cornyn',
#  'rush-holt',
#  'rob-turner',
#  'rand-paul',
#  'hillary-clinton',
#  'christina-romer',
#  'barack-obama',
#  'donald-trump',
#  'rick-perry',
#  'wisconsin-medical-society',
#  'john-cornyn',
#  'mike-dewine',
#  'roy-cooper',
#  'rick-santorum',
#  'chain-email',
#  'friends-voter-owned-elections',
#  'donald-trump',
#  'monica-wehby',
#  'rush-limbaugh',
#  'david-dewhurst',
#  'hillary-clinton',
#  'mitt-romney',
#  'chain-email',
#  'mitt-romney',
#  'americans-united-life',
#  'rod-monroe',
#  'ed-fitzgerald',
#  'joel-keehn',
#  'jack-kingston',
#  'miriam-martinez',
#  'mark-johnson',
#  'alberta-darling',
#  'ted-strickland',
#  'dan-micciche',
#  'joe-biden',
#  'sean-hannity',
#  'john-depetro',
#  'sheldon-whitehouse',
#  'wisconsin-jobs-now',
#  'randy-forbes',
#  'wayne-thorburn',
#  'donald-trump',
#  'todd-staples',
#  'tom-coburn',
#  'barbara-buono',
#  'michele-bachmann',
#  'rich-zipperer',
#  'donald-trump',
#  'family-forward-oregon',
#  'mark-miller',
#  'rick-santorum',
#  'barack-obama',
#  'george-lemieux',
#  'viral-image',
#  'social-media',
#  'barack-obama',
#  'facebook-posts',
#  'reince-priebus',
#  'kevin-de-leon',
#  'bob-mcdonnell',
#  'alex-sink',
#  'dan-kaufman',
#  'susana-martinez',
#  'henry-cuellar',
#  'robert-menendez',
#  'deborah-ross',
#  'blog-posting',
#  'glenford-shibley',
#  'joseph-kyrillos',
#  'hillary-clinton',
#  'judd-gregg',
#  'donald-trump',
#  'barack-obama',
#  'ted-strickland',
#  'americans-prosperity-florida',
#  'facebook-posts',
#  'lamar-smith',
#  'chris-christie',
#  'ohio-department-transportation',
#  'barry-hinckley',
#  'bernie-s',
#  'rick-perry',
#  'george-will',
#  'joe-barton',
#  'jon-kyl',
#  'david-cicilline',
#  'mike-huckabee',
#  'americans-responsible-solutions',
#  'barack-obama',
#  'peter-palumbo',
#  'bettylou-decroce',
#  'marco-rubio',
#  'ted-cruz',
#  'chris-christie',
#  'roy-barnes',
#  'hank-johnson',
#  'carla-smith',
#  'winning-our-future',
#  'pat-mccrory',
#  'mike-pence',
#  'charlie-crist',
#  'don-zimmerman',
#  'michael-savage',
#  'betsy-miller-jones',
#  'ted-strickland',
#  'chain-email',
#  'kay-bailey-hutchison',
#  'marvin-pratt',
#  'rob-cornilles',
#  'dean-wright',
#  'sharron-angle',
#  'david-simas',
#  'patrick-murphy',
#  'reader-email',
#  'jeb-bush',
#  'sean-spicer',
#  'sean-duffy',
#  'helen-glover',
#  'lee-camp',
#  'scott-walker',
#  'paul-ryan',
#  'citizens-united-political-victory-fund',
#  'fred-thompson',
#  'david-clarke-jr',
#  'greg-gutfeld',
#  'rudy-giuliani',
#  'lainey-melnick',
#  'caleb-rowden',
#  'rick-santorum',
#  'oregon-center-public-policy',
#  'republican-party-virginia',
#  'bill-white',
#  'bernie-s',
#  'nancy-pelosi',
#  'brian-kemp',
#  'diane-allen',
#  'chris-christie',
#  'leonidas-raptakis',
#  'howard-dean',
#  'lou-ann-zelenik',
#  'environment-new-jersey',
#  'karl-rove',
#  'scott-brown',
#  'marty-beil',
#  'adam-kinzinger',
#  'rob-portman',
#  'ohio-democratic-party',
#  'joe-sestak',
#  'carly-fiorina',
#  'national-right-life-committee',
#  'funny-or-die',
#  'mitt-romney',
#  'coalition-fair-budget-priorities',
#  'joe-barton',
#  'american-bridge-21st-century',
#  'barack-obama',
#  'susan-stimpson',
#  'kenneth-block',
#  'michael-riley',
#  'donald-trump',
#  'john-mccain',
#  'carly-fiorina',
#  'sarah-palin',
#  'ted-cruz',
#  'david-dewhurst',
#  'pat-toomey',
#  'facebook-posts',
#  'eric-cantor',
#  'nickie-antonio',
#  'barack-obama',
#  'desmond-meade',
#  'hillary-clinton',
#  'ward-armstrong',
#  'john-kasich',
#  'ted-cruz',
#  'back-basics',
#  'terri-lynn-land',
#  'democratic-party-virginia',
#  'blake-rocap',
#  'mitt-romney',
#  'tim-canova',
#  'bernie-s',
#  'donald-trump',
#  'barack-obama',
#  'michael-reese',
#  'campaign-regulate-marijuana-alcohol',
#  'alan-grayson',
#  'greg-abbott',
#  'hillary-clinton',
#  'kamala-harris',
#  'bernie-s',
#  'david-shuster',
#  'john-oliver',
#  'julia-hurley',
#  'mitt-romney',
#  'ellyn-bogdanoff',
#  'republican-state-senators',
#  'earl-blumenauer',
#  'scott-walker',
#  'debbie-wasserman-schultz',
#  'ted-poe',
#  'barack-obama',
#  'senior-citizens-league',
#  'our-daughters-ri',
#  'blog-posting',
#  'bill-clinton',
#  'moveon',
#  'bill-richardson',
#  'ted-cruz',
#  'bill-maher',
#  'laurence-ehrhardt',
#  'marco-rubio',
#  'sarah-palin',
#  'scott-walker',
#  'hillary-clinton',
#  'dana-rohrabacher',
#  'armond-budish',
#  'barack-obama',
#  'republican-national-committee-republican',
#  'jim-demint',
#  'tom-barrett',
#  'blog-posting',
#  'jeb-bush',
#  'ed-gillespie',
#  'kathleen-falk',
#  'texas-automobile-dealers-association',
#  'national-education-association',
#  'ron-johnson',
#  'martin-omalley',
#  'alan-grayson',
#  'john-lewis',
#  'rush-limbaugh',
#  'gina-raimondo',
#  'virginia-house-democratic-caucus',
#  'kitty-boitnott',
#  'deadspin',
#  'mitt-romney',
#  'will-weatherford',
#  'dan-gelber',
#  'lincoln-chafee',
#  'nancy-devaney',
#  'herman-cain',
#  'rob-cornilles',
#  'mitt-romney',
#  'barack-obama',
#  'ted-cruz',
#  'mike-pence',
#  'kelly-ayotte',
#  'sarah-palin',
#  'donald-trump',
#  'scott-walker',
#  'chet-edwards',
#  'glenn-beck',
#  'keep-conservatives-united',
#  'glenn-hegar',
#  'bob-goodlatte',
#  'tommy-thompson',
#  'scott-walker',
#  'jon-runyan',
#  'kelli-ward',
#  'hillary-clinton',
#  'eric-cantor',
#  'senate-conservatives-fund',
#  'ron-johnson',
#  'ohio-democratic-party',
#  'chain-email',
#  'kevin-de-leon',
#  'john-mccain',
#  'kelda-helen-roys',
#  'rick-scott',
#  'hillary-clinton',
#  'addicting-information',
#  'dennis-algiere',
#  'barack-obama',
#  'nancy-pelosi',
#  'michele-bachmann',
#  'ohio-democratic-party',
#  'david-perdue',
#  'allen-west',
#  'ted-gatsas',
#  'chris-christie',
#  'charlotte-nash',
#  'john-carter',
#  'georgia-family-council',
#  'ron-wyden',
#  'michael-turner',
#  'chuck-hagel',
#  'hillary-clinton',
#  'steve-archambault',
#  'chain-email',
#  'will-weatherford',
#  'democratic-senatorial-campaign-committee',
#  'mitt-romney',
#  'kay-bailey-hutchison',
#  'barack-obama',
#  'miami-seaport-alliance',
#  'martin-omalley',
#  'barack-obama',
#  'greater-wisconsin-political-fund',
#  'chain-email',
#  'tom-barrett',
#  'peter-king',
#  'michele-bachmann',
#  'roger-williams',
#  'john-currie',
#  'state-democratic-party-wisconsin',
#  'lone-star-first',
#  'tom-scott',
#  'hillary-clinton',
#  'tim-pawlenty',
#  'united-florida-horsemen',
#  'upendra-chivukula',
#  ...]

# %%
# Preparing meta data

#credit['train'][2]

metadata = {'train':[0]*len(train), 'val':[0]*len(val), 'test':[0]*len(test)}

for i in range(len(train)):
    subject = subjects['train'][i]
    if subject == 0:
        subject = 'None'
        
    #print(subject)
    
    speaker = speakers['train'][i]
    if speaker == 0:
        speaker = 'None'
        
    #print(speaker)
    
    job = jobs['train'][i]
    if job == 0:
        job = 'None'
        
    #print(job)
    
    state = states['train'][i]
    if state == 0:
        state = 'None'
    #print(state)
    affiliation = affiliations['train'][i]
    if affiliation == 0:
        affiliation = 'None'
    #print(affiliation)
    context = contexts['train'][i]
    if context == 0 :
        context = 'None'
    #print(context)
        
    meta = subject + ' ' + speaker + ' ' + job + ' ' + state + ' ' + affiliation + ' ' + context
    
    metadata['train'][i] = meta
    
for i in range(len(val)):
    subject = subjects['val'][i]
    if subject == 0:
        subject = 'None'
        
    #print(subject)
    
    speaker = speakers['val'][i]
    if speaker == 0:
        speaker = 'None'
        
    #print(speaker)
    
    job = jobs['val'][i]
    if job == 0:
        job = 'None'
        
    #print(job)
    
    state = states['val'][i]
    if state == 0:
        state = 'None'
    #print(state)
    affiliation = affiliations['val'][i]
    if affiliation == 0:
        affiliation = 'None'
    #print(affiliation)
    context = contexts['val'][i]
    if context == 0 :
        context = 'None'
    #print(context)
        
    meta = subject + ' ' + speaker + ' ' + job + ' ' + state + ' ' + affiliation + ' ' + context
    
    metadata['val'][i] = meta
    
for i in range(len(test)):
    subject = subjects['test'][i]
    if subject == 0:
        subject = 'None'
        
    #print(subject)
    
    speaker = speakers['test'][i]
    if speaker == 0:
        speaker = 'None'
        
    #print(speaker)
    
    job = jobs['test'][i]
    if job == 0:
        job = 'None'
        
    #print(job)
    
    state = states['test'][i]
    if state == 0:
        state = 'None'
    #print(state)
    affiliation = affiliations['test'][i]
    if affiliation == 0:
        affiliation = 'None'
    #print(affiliation)
    context = contexts['test'][i]
    if context == 0 :
        context = 'None'
    #print(context)
        
    meta = subject + ' ' + speaker + ' ' + job + ' ' + state + ' ' + affiliation + ' ' + context
    
    metadata['test'][i] = meta

# %%
metadata['test']
# Out:
# ['immigration rick-perry Governor Texas republican Radio interview',
#  'jobs katrina-shankland State representative Wisconsin democrat a news conference',
#  "military,veterans,voting-record donald-trump President-Elect New York republican comments on ABC's This Week.",
#  'medicare,message-machine-2012,campaign-advertising rob-cornilles consultant Oregon republican a radio show',
#  'campaign-finance,legal-issues,campaign-advertising state-democratic-party-wisconsin None Wisconsin democrat a web video',
#  'federal-budget,pensions,retirement brendan-doherty None Rhode Island republican a campaign website',
#  'county-budget,county-government,education,taxes stand-children-tennessee Child and education advocacy organization. Tennessee none in a post on Facebook.',
#  'economy,stimulus john-boehner Speaker of the House of Representatives Ohio republican a press release.',
#  'gays-and-lesbians,marriage sean-patrick-maloney Congressman for NY-18 New York democrat a speech at the Democratic National Convention',
#  'foreign-policy mike-pence Governor Indiana republican comments on "Meet the Press"',
#  'elections mike-berlon None Georgia democrat an article',
#  'ethics,message-machine bill-flores Businessman Texas republican a TV ad.',
#  'environment viral-image None None none an image shared on Facebook',
#  'federal-budget,military,poverty facebook-posts Social media posting None none a meme on social media',
#  'city-government,county-government,unions chris-abele Philanthropist Wisconsin none a letter',
#  'education,jobs rick-santorum None Pennsylvania republican a speech',
#  'labor,state-budget tom-niehaus President of the Ohio Senate Ohio republican interviews with reporters',
#  'government-efficiency,government-regulation,polls marsha-blackburn U.S. Representative Tennessee republican a speech to the Freedom Summit in New Hampshire',
#  'health-care hillary-clinton Presidential candidate New York democrat a speech in Des Moines, Iowa.',
#  'economy,history sarah-palin None Alaska republican her book, Going Rogue',
#  "crime,gays-and-lesbians,sexuality chris-sgro Executive Director, Equality NC North Carolina activist a speech urging Charlotte's anti-discrimination ordinance be left intact",
#  'elections marco-rubio U.S. Senator Florida republican a prepared statement',
#  'immigration donald-trump President-Elect New York republican a speech in Phoenix, Ariz.',
#  'drugs,health-care,marijuana marijuana-policy-project None None none a TV ad',
#  'jobs,state-budget republican-party-florida None None republican a TV ad',
#  'sotomayor-nomination,supreme-court lindsey-graham U.S. senator South Carolina republican a Senate hearing',
#  'foreign-policy hillary-clinton Presidential candidate New York democrat the second presidential debate',
#  'education,state-budget republican-national-committee-republican None None republican a blog post.',
#  'climate-change,energy mike-pence Governor Indiana republican MSNBC interview.',
#  'health-care,military cliff-stearns U.S. representative Florida republican a press release',
#  'congress,supreme-court cory-gardner U.S. House of Representatives Colorado republican a talk show',
#  'crime,criminal-justice sarah-palin None Alaska republican a commentary',
#  'baseball,recreation barack-obama President Illinois democrat None',
#  'message-machine,campaign-advertising democratic-congressional-campaign-committee None None democrat an election ad',
#  'elections mamie-locke State senator Virginia democrat an interview.',
#  'health-care,history herman-cain None Georgia republican a video on Cain TV',
#  "health-care rick-scott Governor Florida republican a television ad from Let's Get to Work",
#  'abortion,legal-issues,women jeanne-shaheen Senator New Hampshire democrat an ad',
#  'economy,financial-regulation dennis-kucinich U.S. representative Ohio democrat a television interview',
#  'states,taxes kevin-brady U.S. House member Texas republican a press release',
#  'debates,health-care mitt-romney Former governor Massachusetts republican a presidential debate in Denver',
#  'military,states doonesbury None None none the strip about Greg Abbott and the Jade Helm military exercise',
#  'debates,elections,polls donald-trump President-Elect New York republican a tweet',
#  'environment drew-springer None None republican a press release',
#  'health-care michele-bachmann Congresswoman Minnesota republican a Republican presidential debate in Des Moines, Iowa',
#  'health-care robert-menendez U.S. Senator New Jersey democrat an interview on Richard French Live',
#  'terrorism hillary-clinton Presidential candidate New York democrat a debate in Manchester, N.H.',
#  'economy,history,income,workers barack-obama President Illinois democrat the State of the Union address',
#  'transportation steve-brown Fayette County Commissioner Georgia republican a forum hosted by The Atlanta Journal-Constitution',
#  'abortion,health-care,legal-issues,women hillary-clinton Presidential candidate New York democrat an interview at the Aspen Ideas Festival',
#  'economy,jobs republican-party-florida None None republican a campaign commercial',
#  'guns national-rifle-association None None none a flier.',
#  'consumer-safety,public-safety,technology,transportation jeb-bush None Florida republican a speech at CPAC',
#  'economy,immigration david-dewhurst Lieutenant governor Texas republican his inaugural address.',
#  'children,foreign-policy,immigration,legal-issues jeff-flake U.S. Senator Arizona republican an interview on the PBS "News Hour"',
#  'education,state-budget committee-our-childrens-future Political advocacy group New Jersey none a television ad',
#  'candidates-biography,state-budget steven-costantino House Finance Chairman  Rhode Island democrat a TV commercial ',
#  'abortion hank-johnson U.S. Congressman Georgia democrat an article published in The Atlanta Journal-Constitution',
#  'census michele-bachmann Congresswoman Minnesota republican an interview with the Washington Times.',
#  'immigration russell-pearce None Arizona republican a CNN interview',
#  'crime,criminal-justice,federal-budget,legal-issues barack-obama President Illinois democrat a speech in Washington, D.C. ',
#  "foreign-policy,iraq,terrorism chris-matthews Host of MSNBC's Hardball None none a broadcast on MSNBC",
#  'candidates-biography carlos-curbelo Miami-Dade school board member Florida republican a radio interview',
#  'bankruptcy,debt steven-costantino House Finance Chairman  Rhode Island democrat a statement',
#  'health-care ezekiel-emanuel Vice Provost for Global Initiatives and chair of the Department of Medical Ethics and Health Policy  None democrat a discussion on MSNBC\'s "Up with Steve Kornacki"',
#  'deficit,economy,taxes sherrod-brown U.S. Senator Ohio democrat a CNN interview',
#  'medicare,social-security patrick-murphy None Florida democrat a Florida Senate debate',
#  'economy,federal-budget,stimulus joe-biden U.S. senator Delaware democrat a news release.',
#  'energy bill-richardson Governor New Mexico democrat a debate in Manchester, N.H.',
#  'job-accomplishments,jobs lloyd-doggett Texas congressman in the U.S. Houst of Representatives Texas democrat an interview with ABC TV.',
#  'bipartisanship,congress,congressional-rules,job-accomplishments,voting-record ian-prior Northeast regional spokesman, National Republican Congressional Committee Rhode Island republican a Providence Journal commentary',
#  'candidates-biography,foreign-policy,military priorities-usa-action None None democrat an ad discussed on "Meet the Press"',
#  'state-finances,taxes david-pennington Mayor of Dalton Georgia none a public meeting',
#  'deficit tim-pawlenty None None republican his book, "Courage to Stand: An American Story"',
#  'congressional-rules,federal-budget,health-care ted-cruz Senator Texas republican a news release',
#  'energy,environment,housing,recreation friends-india-point-park None Rhode Island organization a web site',
#  'children,diversity reince-priebus Chairman, Republican National Committee Wisconsin republican comments on "Meet the Press"',
#  'federal-budget,infrastructure,message-machine,transportation,voting-record scott-walker Milwaukee County Executive Wisconsin republican campaign TV and radio ads',
#  'education,jobs,taxes barbara-buono State Senator New Jersey democrat a gubernatorial campaign television ad',
#  'corrections-and-updates,elections,legal-issues donald-trump President-Elect New York republican an interview on "Meet the Press"',
#  'education carole-smith Portland schools superintendent Oregon none a press briefing',
#  'elections,water H204TEXAS-PAC None None none an email blast.',
#  'crime,job-accomplishments david-cicilline mayor of Providence Rhode Island democrat a debate',
#  'federal-budget bill-nelson None Florida democrat Senate floor votes',
#  'candidates-biography,county-budget,county-government gerald-daugherty Businessman Texas republican his campaign website',
#  'occupy-wall-street facebook-posts Social media posting None none Facebook',
#  'energy,foreign-policy,nuclear paul-ryan U.S. Representative Wisconsin republican a news release',
#  'transportation debra-medina Businesswoman Texas republican a debate.',
#  'civil-rights,immigration,privacy,technology facebook-posts Social media posting None none a Facebook post',
#  'message-machine,taxes dave-yost Ohio auditor ohio republican a campaign video',
#  'economy,health-care,workers democratic-national-committee None None none a television ad',
#  'city-budget,crime,job-accomplishments bob-donovan Member of Milwaukee Common Council Wisconsin none an interview',
#  'transportation brett-bittner Executive Director, Libertarian Party of Geo None libertarian an interview',
#  'stimulus george-allen consultant Virginia republican None',
#  'economy julian-castro Mayor, San Antonio Texas democrat his speech at the Texas Democratic Party State Convention in Houston',
#  'elections mike-bennett State Senator Florida republican comments made on the Senate floor.',
#  'health-care,public-health james-carr manager of business operations at a community hospital Virginia libertarian an interview',
#  'transportation safe-routes-schools safety program Oregon none a mailer',
#  'state-budget,weather rick-scott Governor Florida republican comments to the press',
#  'immigration conservative-renewal-pac Political action committee Texas republican a TV ad.',
#  'history barack-obama President Illinois democrat a news conference',
#  'crime kasim-reed None None democrat a press release',
#  'economy,history,income,pundits,taxes rachel-maddow MSNBC host None none HBO\'s "Real Time with Bill Maher"',
#  'florida,foreign-policy charlie-crist None Florida democrat a U.S. Senate debate on CNN’s “State of the Union.”',
#  'climate-change,environment mark-pocan State Assembly member, 78th District Wisconsin democrat a speech',
#  'islam,terrorism bill-oreilly Fox News Channel host None none a broadcast of Fox News\' "The O\'Reilly Factor"',
#  'women priorities-usa-action None None democrat a television ad',
#  'afghanistan,terrorism kendrick-meek None Florida democrat a debate',
#  "education,foreign-policy bob-schieffer Host of CBS' Face the Nation Washington, D.C. journalist comments at a forum at the Center for Strategic and International Studies",
#  'history wolf-blitzer CNN host None none comments on CNN',
#  'debt,deficit chris-christie Governor of New Jersey New Jersey republican an interview on NBC’s “Meet The Press”',
#  'abortion william-obrien Speaker of the House of Representatives New Hampshire republican a Facebook post',
#  'economy,jobs,market-regulation nikki-haley Governor South Carolina republican a speech at the Republican convention',
#  'environment,government-regulation league-conservation-voters None None organization a television ad',
#  'health-care,pundits cenk-uygur None None democrat MSNBC Live',
#  'education,sports mark-emmert NCAA president None none comments on ABC\'s "This Week"',
#  'bipartisanship,candidates-biography donna-campbell Physician Texas republican a speech',
#  'income pat-toomey Candidate for U.S. Senate Pennsylvania republican an interview with Chris Stigall on Talk Radio 1210 WPHT',
#  'guns,message-machine-2012 democratic-national-committee None None none a campaign advertisement',
#  'income,jobs,message-machine-2012,taxes americans-prosperity-new-jersey None None none a television ad posted on YouTube',
#  'message-machine,public-safety,taxes,technology christine-odonnell Candidate for U.S. Senate Delaware republican a campaign commercial',
#  'job-accomplishments,message-machine-2012,state-budget,state-finances crossroads-gps Conservative advocacy group None republican a TV ad.',
#  'history,polls michele-bachmann Congresswoman Minnesota republican a Republican presidential debate in Orlando',
#  'health-care,history ted-cruz Senator Texas republican speech advocating repeal of Obamacare law',
#  'education jason-carter State Senator Georgia democrat forum',
#  'government-regulation,job-accomplishments,jobs,labor,unions,workers mark-pocan State Assembly member, 78th District Wisconsin democrat an interview',
#  'message-machine,campaign-advertising roy-barnes Attorney Georgia democrat a television interview',
#  'bush-administration,pundits,recreation al-sharpton None New York democrat a segment of his MSNBC show, "Politics Nation"',
#  'economy,job-accomplishments,jobs scott-walker Milwaukee County Executive Wisconsin republican a debate',
#  'taxes national-republican-congressional-committee None None republican a blog post on the NRCC website',
#  'abortion,pundits glenn-beck None None none his TV program',
#  'animals,candidates-biography,pundits gail-collins Columnist for the New York Times New York journalist a column',
#  'animals,history matt-bevin Investment manager Kentucky republican a radio interview',
#  'medicare,retirement shelly-moore Teacher Wisconsin democrat a campaign flier',
#  'gambling frank-fahrenkopf Retired president and CEO of the American Gaming Association None republican an opinion piece in the "Miami Herald"',
#  'voting-record connie-mack U.S. representative from Fort Myers Florida republican a U.S. Senate debate',
#  'candidates-biography,china,climate-change,economy,energy,environment,history,science donald-trump President-Elect New York republican a presidential debate',
#  'children,education,state-budget nan-rich candidate for governor Florida democrat a "Tampa Tribune" blog',
#  'criminal-justice,sports mike-wise Columnist, Washington Post None none comments on CNN\'s "State of the Union"',
#  'afghanistan,bush-administration,candidates-biography,ethics,foreign-policy,homeland-security,human-rights,iraq,public-safety,terrorism todd-wilcox None Florida republican a newspaper interview',
#  'jobs,message-machine-2012 democratic-party-virginia None Virginia democrat a web video',
#  'iraq fred-thompson Actor Tennessee republican a debate in Dearborn, Mich.',
#  'crime ohio-public-defenders-office None Ohio none a newspaper interview',
#  'deficit jim-webb writer Virginia democrat a TV interview.',
#  'climate-change,environment sarah-palin None Alaska republican Fairbanks, Alaska',
#  'crime,legal-issues dean-cannon state House speaker Florida republican comments to reporters.',
#  "bipartisanship,debt,deficit,federal-budget steve-latourette Former U.S. representative from Ohio's 11th District Ohio republican an interview on “Fox News Sunday”",
#  'health-care ron-johnson None Wisconsin republican the weekly Republican address',
#  'education,state-budget,unions chris-christie Governor of New Jersey New Jersey republican a speech at the Harvard Graduate School of Education',
#  'candidates-biography occupy-democrats None None organization a post on Facebook',
#  'city-government,gays-and-lesbians,government-regulation,public-safety dan-forest Lieutenant Governor North Carolina republican a tweet',
#  'federal-budget,polls,taxes barack-obama President Illinois democrat a press conference',
#  'federal-budget,social-security hank-johnson U.S. Congressman Georgia democrat a twitter post',
#  'crime,government-regulation,guns hillary-clinton Presidential candidate New York democrat a forum',
#  'state-budget alberta-darling State Senator, 8th District Wisconsin republican an interview',
#  'elections,history joaquin-castro attorney Texas democrat a panel at the Texas Tribune Festival.',
#  'candidates-biography ted-cruz Senator Texas republican the New Hampshire GOP debate',
#  'families,income,poverty paul-ryan U.S. Representative Wisconsin republican a column posted on Medium.com',
#  'guns chain-email None None none a chain email',
#  'foreign-policy,history,new-hampshire-2012 jon-huntsman None Utah republican a campaign appearance in Milford, N.H. ',
#  'children,families,health-care,women carolyn-tomei None None democrat a House floor speech',
#  'education,state-budget,state-finances gina-hinojosa President, Austin Independent School District Board of Trustees Texas none an interview with Kiah Collier, Austin American-Statesman reporter',
#  'county-government john-lee Chair of Clackamas County Republicans Oregon republican in a press release ',
#  'climate-change,environment steve-doocy Co-host of Fox New Channel\'s "Fox and Friends" New York journalist a broadcast of "Fox and Friends."',
#  'state-budget dale-kooyenga State Representative Wisconsin republican a radio interview',
#  'job-accomplishments jim-renacci U.S. representative  Ohio republican a news release',
#  'criminal-justice mark-obenshain State senator Virginia republican a campaign brochure.',
#  'energy,foreign-policy donald-trump President-Elect New York republican an interview with Sean Hannity of Fox News',
#  'education george-lavender State representative Texas republican in Texas House of Representatives debate',
#  'job-accomplishments lee-holloway Chairman, Milwaukee County Boaerd of Supervisors Wisconsin none an interview with a weekly newspaper',
#  "taxes jeanne-shaheen Senator New Hampshire democrat an interview with the editorial board of 'The Telegraph.'",
#  'taxes john-mccain U.S. senator Arizona republican flip-o-meter',
#  "diversity,economy,jobs bernie-s U.S. Senator Vermont independent a Democratic presidential candidates' forum in Rock Hill, S.C.",
#  'health-care,medicaid florida-chamber-commerce None Florida none a report on health care costs',
#  'jobs newt-gingrich Co-host on CNN\'s "Crossfire" Georgia republican a speech',
#  'gambling its-still-bad-idea None Oregon organization a campaign press event',
#  'health-care hillary-clinton Presidential candidate New York democrat in a television ad',
#  'candidates-biography sarah-palin None Alaska republican St. Louis',
#  'health-care eric-hovde None None republican a television interview',
#  'foreign-policy barack-obama President Illinois democrat a statement by campaign spokesman Bill Burton',
#  'polls donald-trump President-Elect New York republican an interview on NBC\'s "Meet the Press"',
#  "education heather-fiorentino superintendent of Pasco County's public schools Florida republican a press release",
#  'criminal-justice,states scott-surovell State delegate Virginia democrat a floor debate.',
#  'abortion,crime wendy-davis state senator Texas democrat an opinion article',
#  'agriculture,taxes american-crossroads None None republican a TV commercial',
#  'elections david-hallock Aide Virginia democrat a forum',
#  "cap-and-trade,climate-change marco-rubio U.S. Senator Florida republican an interview on CBS' Face the Nation",
#  'education charlie-crist None Florida democrat a Tampa Bay Times op-ed',
#  'deficit,job-accomplishments,message-machine-2012,state-budget,state-finances red-white-and-blue-fund None None none a campaign ad',
#  'federal-budget lenny-curry chairman of the Republican Party of Florida Florida republican an interview on "Political Connections"',
#  'nightlife job-itkzkowitz Old City District executive director Pennsylvania none In the Philadelphia Business Journal',
#  'economy,foreign-policy,public-health viral-image None None none a shareable graphic on the Web',
#  'foreign-policy,nuclear donald-trump President-Elect New York republican a Republican presidential debate in North Charleston, S.C.',
#  'candidates-biography reince-priebus Chairman, Republican National Committee Wisconsin republican comments on "The Mike Gallagher Show"',
#  'diversity,history facebook-posts Social media posting None none a meme',
#  'economy rick-perry Governor Texas republican on an episode of Fox & Friends',
#  'drugs,guns,legal-issues rick-perry Governor Texas republican a speech to the Republican Party of Texas convention in Fort Worth.',
#  'campaign-finance,legal-issues,women eric-greitens gubernatorial candidate Missouri republican a press release',
#  'health-care jay-rockefeller U.S. Senator West Virginia democrat a column in the newspaper Roll Call',
#  'civil-rights,diversity,gays-and-lesbians,jobs,workers jeff-merkley U.S. Senator Oregon democrat a press release',
#  'welfare jay-carney White House press secretary District of Columbia none a press White House press briefing',
#  'economy,government-efficiency,jobs rob-portman U.S. senator from Ohio Ohio republican a debate',
#  'candidates-biography,crime,drugs,health-care,legal-issues,marijuana,public-health robert-watson lawyer Rhode Island republican a speech on the House floor',
#  'state-budget,taxes kathie-glass lawyer Texas libertarian a debate.',
#  'government-regulation,guns,legal-issues,public-health,public-safety,recreation,market-regulation,states linda-finn landscape designer Rhode Island democrat a speech during a rally at the Rhode Island state house',
#  'immigration barack-obama President Illinois democrat Las Vegas',
#  'children,education,state-budget,states state-democratic-party-wisconsin None Wisconsin democrat a news release',
#  'education dan-patrick Lieutenant governor-elect Texas republican a state Senate committee hearing April 9, 2013',
#  'health-care,medicare chain-email None None none a chain email',
#  'marriage,poverty rick-santorum None Pennsylvania republican a debate in South Carolina',
#  'nuclear independent-voice-illinois-pac None Illinois  none an attack video advertisement of Congresswoman Tammy Duckworth',
#  'polls carly-fiorina None California republican an interview on CNN\'s "State of the Union"',
#  "taxes republican-party-florida None None republican statements on the party's website.",
#  'environment,jobs scott-suder state Assembly majority leader Wisconsin republican a news release',
#  'federal-budget john-boehner Speaker of the House of Representatives Ohio republican a speech on the House floor.',
#  'abortion wendy-davis state senator Texas democrat a legal brief',
#  'candidates-biography john-mccain U.S. senator Arizona republican an interview with the <i>Kansas City Star</i>',
#  'history,labor,women,workers mitt-romney Former governor Massachusetts republican a graphic posted on his website',
#  'economy,immigration,poverty,welfare donald-trump President-Elect New York republican a speech at the Republican National Convention in Cleveland',
#  'social-security,taxes john-boehner Speaker of the House of Representatives Ohio republican a news conference',
#  'jobs,labor,states enterprise-florida The public-private economic development agency  Florida organization Enterprise Florida radio ads in California',
#  'energy barack-obama President Illinois democrat the State of the Union address',
#  'children,families,marriage,poverty facebook-posts Social media posting None none a meme on the Internet',
#  'economy,message-machine,voting-record lloyd-doggett Texas congressman in the U.S. Houst of Representatives Texas democrat a TV ad',
#  'guns,legal-issues,supreme-court paul-ryan U.S. Representative Wisconsin republican an interview',
#  'jobs,state-budget rick-scott Governor Florida republican a press release',
#  'jobs motion-picture-association-america None None none a press release',
#  'taxes milly-silva Democratic candidate for lieutenant governor; executive vice president of 1199 SEIU New Jersey democrat a speech to an American Legion in Little Ferry',
#  'state-budget,state-finances,taxes robin-vos Wisconsin Assembly speaker Wisconsin republican an interview',
#  'federal-budget michele-bachmann Congresswoman Minnesota republican a press release',
#  'taxes democratic-congressional-campaign-committee None None democrat a video posted on YouTube',
#  'job-accomplishments jeff-scrima Mayor of Waukesha Wisconsin none a series of public statements and actions',
#  'federal-budget,pundits,taxes,abc-news-week george-will Columnist Maryland columnist a roundtable discussion on ABC\'s "This Week with Christiane Amanpour\'\'',
#  'economy,housing nina-turner State senator Ohio democrat an opinion column',
#  'federal-budget florida-democratic-party None Florida democrat an online video',
#  'economy,income jason-carter State Senator Georgia democrat a speech',
#  'economy,jobs,stimulus,workers barack-obama President Illinois democrat a press conference',
#  'candidates-biography,foreign-policy,nuclear hillary-clinton Presidential candidate New York democrat a television ad',
#  'education bernie-s U.S. Senator Vermont independent a CNN interview',
#  'education,government-efficiency john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican a news conference',
#  "civil-rights,guns,legal-issues john-birch-society None None organization an article on the group's website",
#  'state-budget rick-perry Governor Texas republican an interview with The Texas Tribune and Newsweek',
#  'immigration donald-trump President-Elect New York republican a TV ad',
#  'foreign-policy,message-machine-2012,military,terrorism special-operations-opsec-education-fund None None none a web video',
#  'foreign-policy,terrorism barack-obama President Illinois democrat a press availability',
#  'debt,deficit,state-budget jon-bramnick State Assemblyman New Jersey republican a panel discussion for "On The Record with Michael Aron"',
#  'guns michael-bloomberg None New York independent an interview',
#  'economy,federal-budget,jobs,stimulus rand-paul Candidate for U.S. Senate and physician Kentucky republican a response to the State of the Union address',
#  'immigration bill-richardson Governor New Mexico democrat a web interview with ABC News',
#  'housing donald-trump President-Elect New York republican an interview on NBC\'s "Meet the Press"',
#  'economy,jobs,workers hillary-clinton Presidential candidate New York democrat a Democratic presidential debate in Des Moines, Iowa',
#  'immigration ted-cruz Senator Texas republican a press conference ',
#  'environment,jobs anna-kooiman Fox News host None none a segment on "Fox & Friends"',
#  'bush-administration,china,job-accomplishments,trade barack-obama President Illinois democrat a speech at Port of Tampa',
#  "health-care,pundits george-will Columnist Maryland columnist a roundtable segment on ABC's This Week",
#  'guns virginia-center-public-safety None Virginia organization a rally flier',
#  'foreign-policy john-mccain U.S. senator Arizona republican Hempstead, N.Y.',
#  'crime tweets None None none tweets',
#  'public-health,water clean-water-portland None None organization a campaign flier',
#  'job-accomplishments tom-tancredo U.S. representative Colorado republican a Republican debate in Orlando, Fla.',
#  'crime,education,public-safety,state-budget john-kitzhaber Governor of Oregon Oregon democrat in State of the State speech',
#  'congress,congressional-rules,corrections-and-updates dave-brat College professor Virginia republican comments on "Meet the Press"',
#  'candidates-biography fred-thompson Actor Tennessee republican a speech at the Republican National Convention',
#  'corporations,income,taxes one-wisconsin-now None Wisconsin organization a news release and report',
#  'education,federal-budget arne-duncan U.S. Secretary of Education Illinois democrat an appearance on "Face the Nation."',
#  'health-care,jobs,message-machine-2012 us-chamber-commerce None None none a television ad',
#  'sports george-will Columnist Maryland columnist a panel on "Fox News Sunday"',
#  'federal-budget,state-budget,stimulus,transportation scott-walker Milwaukee County Executive Wisconsin republican an announcement of an application for federal stimulus money for rail',
#  'health-care,military,abc-news-week gen-peter-chiarelli Vice Chief of Staff, United States Army None none an interview on "This Week."',
#  'economy,states jeff-mullis State Senator Georgia republican a meeting',
#  'health-care,retirement association-mature-american-citizens None Washington, D.C.  organization a direct mail letter',
#  'iraq votevetsorg None None none a television ad.',
#  'crime,criminal-justice,immigration sean-hannity Radio/TV host None none a slide presented on Hannity’s show during an Austin interview of Donald Trump',
#  'candidates-biography,ethics hilary-rosen None None democrat The Diane Rehm Show',
#  'abortion,health-care matt-gaetz State Representative Florida republican comments before a House subcommittee',
#  'transportation citizens-transportation-mobility None Georgia none a flier',
#  'health-care tommy-thompson None Wisconsin republican a television ad',
#  'iraq chris-dodd U.S. senator Connecticut democrat a TV ad.',
#  'campaign-finance,legal-issues ted-cruz Senator Texas republican a Senate floor speech',
#  'job-accomplishments john-albers None None republican None',
#  'economy,jobs mitt-romney Former governor Massachusetts republican a news release',
#  'congress,guns matt-bevin Investment manager Kentucky republican a television ad',
#  'small-business russ-feingold None Wisconsin democrat in a campaign ad',
#  'health-care,income rand-paul Candidate for U.S. Senate and physician Kentucky republican an interview on Comedy Central\'s "The Daily Show"',
#  'climate-change,energy,environment,foreign-policy,gas-prices eric-hovde None None republican a news release',
#  'abortion,health-care,public-health tennessee-republican-party None Tennessee republican a mailer sent for a state legislative campaign.',
#  'job-accomplishments,message-machine-2012,campaign-advertising,voting-record josh-mandel Ohio treasurer Ohio republican a campaign commercial',
#  'foreign-policy,religion,terrorism jeb-bush None Florida republican an interview on "Face the Nation"',
#  'foreign-policy dick-cheney None None republican an interview on "Fox News Sunday"',
#  'elections hillary-clinton Presidential candidate New York democrat a news conference in Greensburg, Pa.',
#  'federal-budget,health-care barack-obama President Illinois democrat a State of the Union speech',
#  'health-care barack-obama President Illinois democrat a radio ad',
#  'city-government,ethics dave-claunch Businessman Texas none a meeting of the West Lake Hills City Council',
#  'environment,federal-budget,market-regulation allen-west U.S. representative, Florida District 22 Florida republican a TV interview',
#  'congressional-rules,trade chain-email None None none a chain email',
#  'corporations,economy john-mccain U.S. senator Arizona republican None',
#  'public-safety mike-cernovich blogger California none his blog',
#  'energy,environment van-jones Co-host of CNN\'s "Crossfire" Washington, D.C. democrat a segment on CNN\'s "Crossfire"',
#  'energy richard-paglia vice president Spectra Energy None none a TV interview',
#  "afghanistan john-murtha None None democrat the show 'Hardball With Chris Matthews'",
#  'elections mark-neumann Developer and homebuilder Wisconsin republican a website alert',
#  'public-health,state-budget rick-scott Governor Florida republican a Tampa Bay Times interview',
#  'candidates-biography joe-biden U.S. senator Delaware democrat Springfield, Ill.',
#  'elections,history larry-pressler Candidate for U.S. Senate South Dakota independent a campaign forum',
#  'crime,public-safety jennifer-carroll Lieutenant governor Florida republican Capitol news conference',
#  'economy,states,trade lisa-tomasso State Representative Rhode Island democrat a news release.',
#  'corporations,economy,jobs,labor,unions stephen-laffey farmer Colorado republican a radio interview',
#  'taxes mitt-romney Former governor Massachusetts republican a radio ad.',
#  'elections lenny-curry chairman of the Republican Party of Florida Florida republican an "Orlando Sentinel" opinion piece',
#  'ethics john-mccain U.S. senator Arizona republican Green Bay, Wis.',
#  'crime rudy-giuliani Attorney New York republican a debate in Orlando, Fla.',
#  "transportation sid-covington Chairman, Lone Star Rail District Texas none an opinion column by Sid Covington, the district's chairman of the board",
#  'campaign-finance democratic-congressional-campaign-committee None None democrat a news release',
#  'jobs,women,workers barack-obama President Illinois democrat an op-ed for Huffington Post',
#  'state-budget jennifer-shilling State Assembly member, 95th District Wisconsin democrat a tweet',
#  'economy,government-efficiency,government-regulation,small-business,state-budget,state-finances,states,taxes,workers kenneth-block businessman None republican an interview on Rhode Island Public Radio',
#  'elections donald-trump President-Elect New York republican Donald Trump on Sunday, March 13th, 2016, in an interview on "Meet the Press"',
#  'military barack-obama President Illinois democrat a television ad',
#  'agriculture,federal-budget,foreign-policy,poverty sean-duffy Member of the U.S. House Wisconsin republican an interview',
#  'afghanistan,immigration,terrorism rick-perry Governor Texas republican comments on CNN\'s "State of the Union"',
#  'taxes jamie-radtke None Virginia republican a website post.',
#  'jobs rick-perry Governor Texas republican a speech',
#  'corrections-and-updates,water city-austin None Texas none a press release',
#  'drugs,health-care,public-health jeb-bush None Florida republican a column posted on Medium',
#  'health-care barack-obama President Illinois democrat a speech at the White House',
#  'education,state-budget john-kitzhaber Governor of Oregon Oregon democrat an e-mail',
#  'agriculture,families,small-business,taxes robert-hurt U.S. Congressman Virginia republican a statement.',
#  'animals blog-posting None None none Internet posts',
#  'health-care kurt-schrader U.S. representative Oregon democrat a TV interview.',
#  'foreign-policy chris-dodd U.S. senator Connecticut democrat a debate in Miami, Fla.',
#  "immigration jeb-bush None Florida republican an interview on 'Meet the Press.'",
#  'federal-budget john-boehner Speaker of the House of Representatives Ohio republican a public statement',
#  'legal-issues,small-business national-federation-independent-business-wiscons None Wisconsin none a news release',
#  'foreign-policy ben-carson None None republican a GOP debate on CBS',
#  'space marco-rubio U.S. Senator Florida republican an interview with CBS',
#  'elections,women scott-walker Milwaukee County Executive Wisconsin republican an interview',
#  'china,jobs,message-machine-2012 edd-houck None Virginia democrat a TV ad.',
#  'elections,legal-issues anastasia-williams State representative in Rhode Island Rhode Island democrat a House Judiciary Committee hearing',
#  'legal-issues thomas-melsheimer Attorney Texas democrat an op-ed article',
#  'baseball,recreation mitt-romney Former governor Massachusetts republican a debate in St. Petersburg',
#  'abortion,health-care,women Rhode_Island_Catholic None Rhode Island none a newspaper editorial',
#  'corporations,economy,small-business,taxes kay-bailey-hutchison U.S. Senator Texas republican in a Republican gubernatorial debate',
#  'children childrens-healthcare-atlanta None None none a press release',
#  "job-accomplishments,message-machine betty-sutton U.S. representative from Ohio's 13th District Ohio democrat a television campaign ad",
#  'education,elections,health-care,state-budget rebecca-kleefisch Candidate for lieutenant governor Wisconsin republican a video',
#  'state-budget,taxes stephen-sweeney State Senator None democrat an interview on NJToday',
#  'consumer-safety,food-safety,health-care,taxes dennis-kucinich U.S. representative Ohio democrat a news release',
#  'patriotism donald-trump President-Elect New York republican a tweet',
#  'privacy,transportation delia-lopez Real estate investor Oregon republican a statement on campaign website',
#  'legal-issues greater-wisconsin-political-fund None Wisconsin none a TV ad',
#  'congress,history,legal-issues,supreme-court paul-ryan U.S. Representative Wisconsin republican an interview',
#  'elections,health-care ed-schultz MSNBC television host None none a broadcast of "The Ed Show"',
#  'crime cory-booker U.S. senator New Jersey democrat an interview on "Meet the Press"',
#  'education gail-collins Columnist for the New York Times New York journalist in her New York Times column',
#  'crime,guns sam-adams Mayor of Portland Oregon democrat a city council meeting',
#  'fake-news political-insider None None none a post on their website',
#  'economy,stimulus barack-obama President Illinois democrat a news conference',
#  'health-care charles-krauthammer None None none an interview on "The O\'Reilly Factor"',
#  'transportation freedom-partners-action-fund None None organization a television ad',
#  'elections,energy troy-fraser Businessman, investor Texas republican a Texas Senate committee hearing.',
#  'economy,jobs,states scott-walker Milwaukee County Executive Wisconsin republican a speech to the Republican National Convention in Tampa',
#  'economy,energy,environment,science,technology james-oneil attorney Rhode Island democrat an appearance on "10 News Conference."',
#  'education,state-budget rick-scott Governor Florida republican a campaign commercial',
#  'federal-budget,abc-news-week john-boehner Speaker of the House of Representatives Ohio republican an interview on ABC\'s "This Week\'\'',
#  'campaign-advertising,trade john-boccieri Former member of Congress Ohio democrat a debate',
#  'education tommy-thompson None Wisconsin republican his campaign Web site.',
#  'economy,poverty lloyd-doggett Texas congressman in the U.S. Houst of Representatives Texas democrat a speech delivered to U.S. House of Representatives.',
#  'legal-issues hillary-clinton Presidential candidate New York democrat a speech at the Democratic National Convention.',
#  'abortion,health-care national-right-life-committee None None none a press release',
#  'guns adrian-garcia 29th Congressional District candidate Texas democrat a campaign news release',
#  'health-care barack-obama President Illinois democrat None',
#  'economy,jobs rick-santorum None Pennsylvania republican comments on CNN\'s "State of the Union."',
#  'economy,poverty,sports,state-budget,state-finances,transparency tyrone-brooks State representative Georgia democrat a statement',
#  'economy david-wyss None None none a newspaper article',
#  'foreign-policy hillary-clinton Presidential candidate New York democrat a debate in Cleveland',
#  'history,taxes ron-paul U.S. representative Texas republican a Republican presidential debate in South Carolina',
#  'candidates-biography rudy-giuliani Attorney New York republican St. Paul, Minn.',
#  'workers linda-chavez-thompson Labor organizer Texas democrat a speech to the Central Texas Democratic Forum',
#  'foreign-policy,terrorism jeb-bush None Florida republican a GOP debate on CNN',
#  'stimulus kay-bailey-hutchison U.S. Senator Texas republican an op-ed piece.',
#  'iraq sarah-palin None Alaska republican St. Louis',
#  'medicaid,state-budget,state-finances scott-walker Milwaukee County Executive Wisconsin republican a television interview',
#  'economy,jobs,workers hillary-clinton Presidential candidate New York democrat a column posted on Medium.com',
#  'federal-budget,hunger gwyneth-paltrow Actress California democrat a tweet',
#  'environment,government-regulation,water doug-whitsett state senator Oregon republican a legislative hearing',
#  'elections,legal-issues,supreme-court mark-pocan State Assembly member, 78th District Wisconsin democrat a speech',
#  'campaign-finance,elections ohio-republican-party None Ohio republican an emailed statement',
#  'patriotism chain-email None None none a message circulated to many people.',
#  'state-budget chris-taylor None None democrat a press release',
#  'job-accomplishments,jobs george-allen consultant Virginia republican campaign literature.',
#  'elections,polls chris-christie Governor of New Jersey New Jersey republican an interview on CNBC',
#  'census,income jason-carter State Senator Georgia democrat television ad',
#  'baseball sherrod-brown U.S. Senator Ohio democrat an appearance on MSNBC',
#  'health-care texas-democratic-party Political party Texas democrat news release',
#  'guns johnny-isakson U.S. Senator Georgia republican None',
#  'education,immigration mitt-romney Former governor Massachusetts republican a campaign video.',
#  'pop-culture john-mccain U.S. senator Arizona republican a Twitter message',
#  'city-budget,county-budget,education,pensions,state-budget donald-mceachin State senator Virginia democrat a speech.',
#  'crime,criminal-justice stephen-ucci Rhode Island legislator Rhode Island democrat a news release',
#  'federal-budget,health-care,medicare peter-orszag Director of the Office of Management and Budget None democrat an interview on CNN\'s "State of the Union"',
#  'retirement,social-security harry-reid Senate Democratic Leader Nevada democrat a speech at the DNC',
#  'congressional-rules,federal-budget,income george-lemieux None Florida republican a press release',
#  'guns,polls dianne-feinstein U.S. Senator California democrat a speech on the Senate floor',
#  'oil-spill charlie-crist None Florida democrat a speech at the Florida Association of Counties conference',
#  'elections viral-image None None none a viral image',
#  'pundits peter-lavelle Crosstalk host on RT None journalist a segment on RT\'s "CrossTalk"',
#  'foreign-policy barack-obama President Illinois democrat a convention speech',
#  'elections,foreign-policy reince-priebus Chairman, Republican National Committee Wisconsin republican comments on "Meet the Press"',
#  'candidates-biography,elections,environment,legal-issues edwin-pacheco Democratic party chairman Rhode Island democrat a press release from the Rhode Island Democratic Party',
#  'elections john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican a speech to lobbyists',
#  'elections,supreme-court john-lewis Congressman Georgia democrat newspaper column',
#  'health-care,taxes matt-wand Attorney Oregon republican a campaign mailer',
#  'energy,environment donald-trump President-Elect New York republican a speech on energy policy',
#  'government-efficiency,jobs matt-lundy State representative Ohio democrat a news release',
#  'history,taxes jim-webb writer Virginia democrat a web post.',
#  'elections hillary-clinton Presidential candidate New York democrat a speech in Charleston, W.Va.',
#  'voting-record dan-sebring Auto repair shop owner Wisconsin republican a radio ad',
#  'candidates-biography,education state-democratic-party-wisconsin None Wisconsin democrat a web posting',
#  'education jeb-bush None Florida republican a CPAC appearance',
#  'taxes,transportation tom-graves None None republican a speech',
#  'stimulus john-mccain U.S. senator Arizona republican a report',
#  'technology,trade donald-trump President-Elect New York republican a campaign speech',
#  'federal-budget barack-obama President Illinois democrat a speech in Cleveland, Ohio.',
#  'state-budget jim-doyle Lawyer Wisconsin democrat a statutorially required report on the state budget deficit',
#  'drugs donald-trump President-Elect New York republican the third presidential debate',
#  'elections jonathan-karl ABC News chief White House correspondent None journalist a conversation on ABC\'s "This Week"',
#  'economy,education,message-machine republican-governors-association None Washington, D.C. republican a television ad',
#  'iraq barack-obama President Illinois democrat Orlando, Fla.',
#  'city-budget,labor afscme None None none a letter to members',
#  'crime,criminal-justice,job-accomplishments,public-safety greg-abbott governor Texas republican a campaign television ad',
#  'sports john-oliver Host, Last Week Tonight None none a segment on "Last Week Tonight"',
#  'candidates-biography george-lemieux None Florida republican a Web ad',
#  'military marco-rubio U.S. Senator Florida republican a speech at the Iowa State Fair',
#  'education,foreign-policy,poverty,public-health,women unicef None None none an article on Medium',
#  'congress,elections,job-accomplishments,message-machine-2012 campaign-primary-accountability Political action committee Texas none a campaign commercial',
#  'homeland-security,human-rights,immigration michael-j-gardiner Lawyer Rhode Island republican a posting on his website',
#  'climate-change,environment,transportation george-will Columnist Maryland columnist a TV talk show',
#  'candidates-biography,diversity,elections jeb-bush None Florida republican a Telemundo News interview',
#  "health-care barack-obama President Illinois democrat an interview on NBC's Today show",
#  'cap-and-trade,climate-change,corrections-and-updates,message-machine-2012 rick-santorum None Pennsylvania republican a video ad airing in Michigan',
#  'economy,jobs john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican a television interview',
#  'economy bill-white Former mayor of Houston Texas democrat an e-mail',
#  'elections brian-kemp Secretary of State Georgia republican None',
#  'campaign-finance mark-neumann Developer and homebuilder Wisconsin republican a campaign radio ad',
#  'state-budget,state-finances dennis-richardson state representative Oregon republican a newsletter',
#  'economy john-mccain U.S. senator Arizona republican an advertisement',
#  'campaign-finance,congress,elections tammy-baldwin U.S. Representative Wisconsin democrat a campaign email',
#  'elections,taxes chain-email None None none a chain email forwarded by an Austin American-Statesman reader.',
#  'civil-rights,pundits glenn-beck None None none comments on his radio program',
#  'foreign-policy,terrorism donald-trump President-Elect New York republican a rally in Raleigh, N.C.',
#  'corporations,economy,government-regulation,income,labor,poverty,states,wealth,workers erin-lynch Rhode Island state senator, lawyer Rhode Island democrat a speech on the floor of the Rhode Island Senate',
#  'bush-administration joe-biden U.S. senator Delaware democrat a rally in Springfield, Ill.',
#  'guns,military nicholas-kristof None None none his column in the New York Times',
#  'economy,energy,environment,jobs sherrod-brown U.S. Senator Ohio democrat a debate',
#  "message-machine-2012,taxes Yes-on-79 None Oregon none a state voters' pamphlet argument",
#  'immigration jeff-sessions None Alabama republican an interview on CBS’ “Face the Nation”',
#  'civil-rights,crime,foreign-policy,homeland-security,technology hillary-clinton Presidential candidate New York democrat a Presidential debate',
#  'economy,federal-budget,stimulus,taxes james-langevin Congressman Rhode Island democrat an online forum on ProJo.com',
#  'foreign-policy john-kerry Secretary of State Massachusetts democrat comments on NBC\'s "Meet the Press"',
#  'redistricting richard-saslaw State Senate Minority Leader Virginia democrat an interview.',
#  'debates,elections marco-rubio U.S. Senator Florida republican an interview on "This Week."',
#  'economy,jobs adam-hasner None Florida republican a tweet',
#  "candidates-biography,crime todd-staples state agriculture commissioner Texas republican a consultant's e-mail to PolitiFact Texas.",
#  'china,trade donald-trump President-Elect New York republican the fourth GOP primary debate.',
#  'education,women mitch-mcconnell Senate minority leader Kentucky republican remarks to voters in Kentucky',
#  'education,state-budget mary-burke Madison school board member Wisconsin democrat an interview',
#  'corporations,small-business,taxes paul-ryan U.S. Representative Wisconsin republican an interview',
#  'corporations,energy,environment,message-machine-2012,stimulus americans-prosperity None None none a TV ad',
#  'health-care americas-health-insurance-plans Trade group representing the health insurance industry Washington, D.C. none an advertisement',
#  'candidates-biography,debt,deficit,economy,federal-budget hillary-clinton Presidential candidate New York democrat a Presidential debate',
# ...
#  'corporations,economy joe-biden U.S. senator Delaware democrat a “Face the Nation” interview',
#  'health-care barack-obama President Illinois democrat Cleveland, Ohio',
#  'deficit,federal-budget ohio-democratic-party None Ohio democrat a news release',
#  'taxes florida-democratic-party None Florida democrat a news release',
#  'county-budget,county-government leah-vukmir Member of state Assembly Wisconsin republican a news release',
#  "diversity,immigration,religion donald-trump President-Elect New York republican an interview with Fox News' Sean Hannity",
#  'drugs rick-scott Governor Florida republican testimony before Congress.',
#  'campaign-finance,candidates-biography,crime,environment occupy-democrats None None organization a Facebook photo post',
#  'economy,foreign-policy john-kerry Secretary of State Massachusetts democrat comments on CBS\' "Face the Nation"',
#  'agriculture,environment,federal-budget george-allen consultant Virginia republican a blog post.',
#  'agriculture,children,federal-budget,hunger rick-perry Governor Texas republican a speech in Iowa',
#  'health-care eileen-brady None None democrat in a campaign ad',
#  'jobs,message-machine,trade russ-feingold None Wisconsin democrat campaign TV and radio ads',
#  'economy,income lisa-hamler-fugitt Executive director of the Ohio Association of Second Harvest Foodbanks Ohio none testimony before a House subcommittee',
#  'bankruptcy,corrections-and-updates john-oliver Host, Last Week Tonight None none a broadcast of HBO\'s "Last Week Tonight"',
#  'debt rick-scott Governor Florida republican a TV interview',
#  'state-budget,state-finances chris-christie Governor of New Jersey New Jersey republican a speech at the Republican National Convention in Tampa',
#  'ethics,message-machine chuck-riley State representative Oregon democrat a television ad',
#  'immigration blog-posting None None none social media posts, blogs',
#  'federal-budget mitt-romney Former governor Massachusetts republican an interview on CNBC.',
#  'crime,criminal-justice,government-regulation,guns mayors-against-illegal-guns None None organization a website post',
#  'economy donald-trump President-Elect New York republican a campaign speech',
#  'health-care,hunger,poverty meals-wheels-rhode-island None Rhode Island organization a fundraising letter',
#  'congress,deficit,economy,federal-budget american-action-network None None republican a newspaper ad',
#  'candidates-biography national-republican-senatorial-committee None None republican a TV ad',
#  'campaign-finance,financial-regulation,message-machine-2014 jeanne-shaheen Senator New Hampshire democrat a radio ad',
#  'federal-budget,taxes mark-warner U.S. Senator Virginia democrat n Op/Ed in The Financial Times',
#  'jobs chris-christie Governor of New Jersey New Jersey republican a news conference',
#  'abortion,bipartisanship,candidates-biography,children,china,environment,federal-budget,message-machine-2012 restore-our-future super PAC None republican a television ad',
#  'poverty john-edwards former senator North Carolina democrat a speech in Americus, Ga.',
#  'state-budget,state-finances bruce-starr State senator Oregon republican a floor speech',
#  'campaign-finance,county-government,crime,criminal-justice,elections scott-walker Milwaukee County Executive Wisconsin republican a TV interview',
#  'history john-mccain U.S. senator Arizona republican a campaign event in St. Petersburg',
#  'economy barack-obama President Illinois democrat Nashville, Tenn.',
#  'education,states rick-perry Governor Texas republican a speech at the National Press Club',
#  'campaign-finance,legal-issues scott-walker Milwaukee County Executive Wisconsin republican a TV interview',
#  'economy,federal-budget barack-obama President Illinois democrat a Republican retreat in Baltimore',
#  'marriage,message-machine,religion,women alan-grayson U.S. House of Representatives Florida democrat a TV ad.',
#  'city-government,message-machine-2012,women mary-nolan Represents Southwest Portland in Oregon House Oregon democrat a campaign press release',
#  'religion mike-huckabee author Arkansas republican Manchester, N.H.',
#  'Alcohol,health-care,medicare viral-media-reports none Georgia none  social media and in print',
#  'health-care eric-cantor House Majority Leader Virginia republican a TV interview.',
#  'corporations,trade,workers donald-trump President-Elect New York republican a rally in Delaware, Ohio',
#  'criminal-justice nathan-deal None None republican a speech',
#  'health-care americans-prosperity None None none a YouTube ad',
#  'transportation karen-huber Travis County commissioner, Precinct 3 Texas democrat an Austin American-Statesman news stor',
#  'congress,federal-budget,homeland-security,terrorism lloyd-doggett Texas congressman in the U.S. Houst of Representatives Texas democrat oped commentary',
#  'unions,workers thomas-perez Secretary of Labor Maryland democrat an interview.',
#  'economy,stimulus eric-cantor House Majority Leader Virginia republican an interview on the Fox News Channel.',
#  'environment,science grover-fugate Executive director of the Rhode Island Coastal Resources Management Council Rhode Island state-official a TV interview',
#  'china,message-machine-2012,trade barack-obama President Illinois democrat a television ad',
#  'education dan-patrick Lieutenant governor-elect Texas republican a Texas Tribune interview.',
#  'jobs john-nygren State Assembly, 89th District Wisconsin republican a press conference',
#  'crime,criminal-justice,immigration julian-castro Mayor, San Antonio Texas democrat Univision debate on immigration',
#  'education bill-white Former mayor of Houston Texas democrat in a TV ad',
#  'transportation john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican an interview televised March 22 on “State of Ohio”',
#  "military lynn-westmoreland None None republican a press release on the House GOP's blog.",
#  'economy,income,population,states pat-mccrory Governor of North Carolina North Carolina republican an official announcement',
#  'federal-budget,health-care,medicare,retirement stephanie-cutter Co-host on CNN\'s "Crossfire" Massachusetts democrat an interview on "Face the Nation"',
#  'terrorism blog-posting None None none an article',
#  'job-accomplishments,transportation scott-walker Milwaukee County Executive Wisconsin republican a statement issued by a transition team leader',
#  'afghanistan,foreign-policy rachel-maddow MSNBC host None none a broadcast of the "Rachel Maddow Show"',
#  'economy,jobs john-kitzhaber Governor of Oregon Oregon democrat a speech.',
#  'energy,campaign-advertising sierra-club None None none a TV ad',
#  'economy,jobs,message-machine-2012,taxes crossroads-gps Conservative advocacy group None republican a television ad',
#  'cap-and-trade,climate-change,environment newt-gingrich Co-host on CNN\'s "Crossfire" Georgia republican a Republican presidential candidate forum',
#  'pop-culture,sports facebook-posts Social media posting None none in posts on Facebook',
#  'environment new-jersey-sierra-club None None none a press release',
#  'agriculture,animals,food-safety,public-health,urban centers-disease-control federal agency Georgia none radio interview',
#  'congress,oil-spill bill-nelson None Florida democrat a TV attack ad',
#  'taxes,wealth steve-rothman None None democrat a campaign video posted on YouTube',
#  'foreign-policy,military,abc-news-week robin-wright Senior fellow, U.S. Institute of Peace Washington, D.C. none an interview on ABC\'s "This Week with Christiane Amanpour"',
#  'economy,jobs,workers rick-scott Governor Florida republican a gubernatorial debate',
#  'iraq,terrorism julie-pace White House reporter, Associated Press Washington journalist a question to White House Press Secretary Josh Earnest',
#  'crime charlie-crist None Florida democrat a campaign website',
#  'environment ron-bergeron None None state-official a Florida Fish and Wildlife Conservation Commission meeting',
#  'elections,ethics eve-schatelowitz-alcantar Attorney Texas democrat a response to League of Women Voters of Texas.',
#  'medicare,poverty ron-kind U.S. representative Wisconsin  democrat a news release',
#  'federal-budget,pundits bill-oreilly Fox News Channel host None none an interview on "The Daily Show"',
#  'deficit,federal-budget,new-hampshire-2012 jon-huntsman None Utah republican an NBC-Facebook debate in Concord, N.H.',
#  'ethics democratic-national-committee None None none None',
#  'economy,trade sherrod-brown U.S. Senator Ohio democrat a news release',
#  'health-care,medicare,message-machine scott-bruun State representative Oregon republican a television ad',
#  'economy john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican an appearance on "Meet the Press"',
#  'education greg-abbott governor Texas republican interview on Fox News Sunday',
#  'education,immigration rick-scott Governor Florida republican a CNN debate',
#  'civil-rights,education john-lewis Congressman Georgia democrat an op-ed',
#  'trade ted-cruz Senator Texas republican the Republican debate in Miami',
#  'deficit,economy,stimulus national-republican-senatorial-committee None None republican a press release.',
#  "economy,jobs jeb-bush None Florida republican a speech at Gov. Rick Scott's economic summit in Orlando",
#  'candidates-biography charlie-crist None Florida democrat a TV advertisement',
#  'elections,environment,government-regulation salmon-all None None organization a guest column',
#  'candidates-biography,taxes greater-wisconsin-political-fund None Wisconsin none campaign mailer',
#  'congress,corrections-and-updates,voting-record ending-spending-action-fund None None independent a campaign ad',
#  'state-budget donald-carcieri Governor Rhode Island republican a commentary in The Providence Journal',
#  'economy,jobs,taxes barack-obama President Illinois democrat a speech. ',
#  'campaign-finance,energy,environment robby-mook Campaign manager for Hillary Clinton New York democrat a Medium post',
#  'corrections-and-updates,debates,foreign-policy barack-obama President Illinois democrat a presidential debate',
#  'diversity,income,poverty bernie-s U.S. Senator Vermont independent comments on "Meet the Press."',
#  'labor,new-hampshire-2012 mitt-romney Former governor Massachusetts republican a Republican presidential primary debate',
#  'health-care,veterans michelle-nunn Chief Executive Officer, Points of Light Foundation Georgia democrat an interview',
#  'gays-and-lesbians,legal-issues,religion viral-image None None none a Facebook post',
#  "health-care,jobs rick-scott Governor Florida republican a television ad from Let's Get to Work",
#  'candidates-biography,corporations,jobs anonymous-cyber-squatter Unknown Unknown none a website',
#  'bankruptcy,baseball,economy,history,jobs,message-machine-2014,campaign-advertising,state-budget,state-finances dawson-hodgson State Senator Rhode Island republican a radio commercial',
#  'candidates-biography mitt-romney Former governor Massachusetts republican an interview with NBC\'s "Meet the Press"',
#  'elections,government-efficiency kenneth-block businessman None republican a newspaper commentary',
#  'corrections-and-updates,food-safety john-oliver Host, Last Week Tonight None none a segment on "Last Week Tonight"',
#  'state-budget rick-scott Governor Florida republican his State of the State speech.',
#  'economy,education,government-efficiency,state-budget dawson-hodgson State Senator Rhode Island republican a radio interview',
#  'job-accomplishments,message-machine julie-lassa State Senator, 24th District Wisconsin democrat a campaign TV ad',
#  'diversity city-beaverton city Oregon none a press release',
#  'public-health blog-posting None None none a informal news website',
#  'ethics viral-image None None none a post shared on Facebook',
#  'energy georgia-politicians None None none  political campaign',
#  'federal-budget david-perdue U.S. Senate candidate Georgia republican television ad',
#  'economy,federal-budget,jobs,stimulus eric-cantor House Majority Leader Virginia republican a press release.',
#  'candidates-biography,city-budget,city-government,debt,deficit,economy,history,taxes,unions angel-taveras Mayor of Providence Rhode Island democrat a fundraising letter',
#  'corrections-and-updates,education rick-santorum None Pennsylvania republican an interview on "Face the Nation."',
#  'health-care anthony-weiner None New York democrat an interview on "Fox and Friends"',
#  'energy,taxes bill-johnson U.S. representative Ohio republican a news conference',
#  'energy,jobs tom-graves None None republican a press release',
#  'bush-administration barack-obama President Illinois democrat St. Paul, Minn.',
#  'message-machine-2012,taxes steve-rothman None None democrat a video posted on YouTube',
#  'candidates-biography,income paul-manafort None None republican an interview on "State of the Union"',
#  'city-government,recreation barry-bone Businessman Texas none an opinion column in the Westlake Picayune.',
#  'elections,redistricting voters-first-ohio None Ohio none a news story',
#  'candidates-biography,economy,florida jeb-bush None Florida republican a campaign video',
#  'federal-budget,military,voting-record ted-cruz Senator Texas republican a Republican presidential debate in North Charleston, S.C.',
#  'voting-record catherine-cortez-masto None Nevada democrat a Nevada U.S. Senate debate.',
#  'energy mitt-romney Former governor Massachusetts republican the second presidential debate',
#  'criminal-justice,drugs,florida,public-safety pam-bondi None Florida republican a campaign commercial',
#  'income,jobs alicia-menendez None None none comments on ABC\'s "This Week"',
#  'iraq joe-biden U.S. senator Delaware democrat a television interview',
#  'state-budget john-kasich Governor of Ohio as of Jan. 10, 2011 Ohio republican a news conference',
#  "education,elections paul-saldana Community advocate, member and vice presidentof Austin Independent School District Board of Trustees Texas democrat a civic summit hosted by Austin's KLRU-TV",
#  'federal-budget,health-care,medicaid,medicare,social-security josh-mandel Ohio treasurer Ohio republican a letter to Ohio lawmakers',
#  'economy,jobs,message-machine,state-budget,transparency ted-strickland Former Ohio governor Ohio democrat a campaign video',
#  'federal-budget johnny-isakson U.S. Senator Georgia republican a press release',
#  'state-budget,state-finances michele-bachmann Congresswoman Minnesota republican the Blooomberg/Washington Post Republican presidential debate.',
#  'federal-budget,science rush-holt None None democrat an opinion article',
#  'education,jobs boyd-richie Texas Democratic Party chair Texas democrat a press release.',
#  "health-care charles-boustany None Louisiana republican response to President Obama's health care address to Congress",
#  'campaign-finance,candidates-biography marco-rubio U.S. Senator Florida republican comments at a GOP debate in Cleveland',
#  'candidates-biography david-perdue U.S. Senate candidate Georgia republican a video',
#  'jobs,small-business,taxes chris-abele Philanthropist Wisconsin none a campaign news release',
#  'elections,pundits rachel-maddow MSNBC host None none an episode of her MSNBC show',
#  'civil-rights,crime,guns barack-obama President Illinois democrat the State of the Union Address',
#  'immigration ted-poe U.S. House Representative Texas republican an opinion piece',
#  'economy phil-gingrey U.S. Congressman Georgia republican a press statement',
#  'candidates-biography tom-leppert Businessman Texas republican a campaign statement.',
#  'candidates-biography,china,economy,energy terry-mcauliffe Governor Virginia democrat a news conference.',
#  'energy,jobs russ-girling CEO TransCanada None none comments on ABC\'s "This Week"',
#  'campaign-finance,state-budget,transportation mike-mccabe None None none a speech',
#  'foreign-policy,iraq,terrorism ted-cruz Senator Texas republican comments on CNN\'s "State of the Union"',
#  'china,jobs,message-machine-2012,stimulus americans-tax-reform None None none a mailer to voters',
#  'poverty oxfam-america None None none a tweet',
#  ...]

# %%
# Credit score calculation
credit_score = {'train':[0]*len(train), 'val':[0]*len(val), 'test':[0]*len(test)}
for i in range(len(train)):
    credit = credits['train'][i]
    if sum(credit) == 0:
        score = 0.5
    else:
        score = (credit[3]*0.2 + credit[2]*0.5 + credit[0]*0.75 + credit[1]*0.9 + credit[4]*1)/(sum(credit))
    credit_score['train'][i] = score
    
for i in range(len(val)):
    credit = credits['val'][i]
    if sum(credit) == 0:
        score = 0.5
    else:
        score = (credit[3]*0.2 + credit[2]*0.5 + credit[0]*0.75 + credit[1]*0.9 + credit[4]*1)/(sum(credit))
    credit_score['val'][i] = score
    
for i in range(len(test)):
    credit = credits['test'][i]
    if sum(credit) == 0:
        score = 0.5
    else:
        score = (credit[3]*0.2 + credit[2]*0.5 + credit[0]*0.75 + credit[1]*0.9 + credit[4]*1)/(sum(credit))
    credit_score['test'][i] = score

# %%
for i in range(len(test)):
    credit = credits['test'][i]
    if sum(credit) == 0:
        score = 0.5
    else:
        score = (credit[3]*0.2 + credit[2]*0.5 + credit[0]*0.75 + credit[1]*0.9 + credit[4]*1)/(sum(credit))
    credit_score['test'][i] = score

# %%
credit_score['train']
# Out:
# [0.9,
#  0.35,
#  0.5031712473572939,
#  0.8826923076923077,
#  0.5407692307692308,
#  0.5181818181818182,
#  0.5833333333333334,
#  0.5031712473572939,
#  0.75,
#  0.2,
#  0.5687500000000001,
#  0.46774193548387094,
#  0.61875,
#  0.3,
#  0.6431818181818182,
#  0.46774193548387094,
#  0.5031712473572939,
#  0.7208333333333333,
#  0.63,
#  0.55,
#  0.6428571428571429,
#  0.62,
#  0.5104072398190046,
#  0.6954545454545454,
#  0.75,
#  0.6711538461538461,
#  0.5104072398190046,
#  0.75,
#  0.7,
#  0.6,
#  0.5104072398190046,
#  0.75,
#  0.825,
#  0.573076923076923,
#  0.6499999999999999,
#  0.6846846846846847,
#  0.4916666666666667,
#  0.5,
#  1.0,
#  0.46249999999999997,
#  0.5763565891472868,
#  0.7,
#  0.7208333333333333,
#  0.6130434782608696,
#  0.4583333333333333,
#  0.46774193548387094,
#  0.9125,
#  0.7278846153846155,
#  1.0,
#  0.8826923076923077,
#  0.651048951048951,
#  0.7216666666666666,
#  0.7441176470588236,
#  0.475,
#  0.7583333333333333,
#  0.5,
#  0.5,
#  0.7476993865030674,
#  0.6113013698630136,
#  0.2,
#  0.4428571428571429,
#  0.65125,
#  0.75,
#  0.475,
#  0.9500000000000001,
#  0.75,
#  0.61875,
#  0.7476993865030674,
#  0.75,
#  0.573076923076923,
#  0.752,
#  0.61875,
#  0.2,
#  0.2,
#  0.5031712473572939,
#  0.6431818181818182,
#  0.5,
#  0.75,
#  0.659375,
#  0.625,
#  0.5166666666666667,
#  0.5,
#  0.9,
#  0.5058823529411764,
#  0.5,
#  0.555,
#  0.4375,
#  0.4428571428571429,
#  0.5637096774193548,
#  0.9,
#  0.6113013698630136,
#  0.651048951048951,
#  0.2,
#  0.61875,
#  0.61875,
#  0.6357142857142857,
#  0.2,
#  0.5666666666666667,
#  0.75,
#  0.2,
#  0.825,
#  1.0,
#  0.625,
#  0.5820000000000001,
#  0.7476993865030674,
#  0.5031712473572939,
#  0.5,
#  0.651048951048951,
#  0.39999999999999997,
#  0.752,
#  0.6093333333333334,
#  0.5829268292682926,
#  0.3583333333333334,
#  0.5692982456140352,
#  0.5031712473572939,
#  0.4727272727272727,
#  0.51875,
#  0.8826923076923077,
#  0.5637096774193548,
#  0.6846846846846847,
#  0.5104072398190046,
#  0.47500000000000003,
#  0.2,
#  0.659375,
#  0.475,
#  0.4833333333333333,
#  0.5104072398190046,
#  0.8826923076923077,
#  0.9249999999999999,
#  0.5863636363636364,
#  0.2,
#  0.6113013698630136,
#  0.5763565891472868,
#  0.573076923076923,
#  0.6166666666666667,
#  0.95,
#  0.5,
#  0.6892857142857143,
#  0.7986486486486487,
#  0.61875,
#  0.6333333333333333,
#  0.48333333333333334,
#  0.7111111111111111,
#  0.5104072398190046,
#  0.5192307692307693,
#  0.5031712473572939,
#  0.4983870967741935,
#  0.6382352941176471,
#  0.8400000000000001,
#  0.7476993865030674,
#  0.61875,
#  0.7985294117647058,
#  0.7,
#  0.4166666666666667,
#  0.8333333333333334,
#  0.68,
#  0.6571428571428571,
#  0.655,
#  0.5,
#  0.46774193548387094,
#  0.701851851851852,
#  0.5692982456140352,
#  0.9125,
#  0.5,
#  0.5763565891472868,
#  0.6109375,
#  0.8826923076923077,
#  1.0,
#  0.484375,
#  0.6071428571428571,
#  0.4714285714285715,
#  0.75,
#  0.3,
#  0.65125,
#  0.3,
#  0.9,
#  0.6166666666666667,
#  0.5,
#  0.5259259259259259,
#  0.5938271604938272,
#  0.5,
#  0.701851851851852,
#  0.5,
#  0.5,
#  0.6409090909090909,
#  0.6261904761904762,
#  0.4462962962962963,
#  0.45999999999999996,
#  0.6714285714285715,
#  0.7363636363636363,
#  0.2,
#  0.485,
#  0.9125,
#  0.7702127659574469,
#  0.5,
#  0.5104072398190046,
#  0.6892857142857143,
#  0.46774193548387094,
#  0.46774193548387094,
#  0.6846846846846847,
#  0.2,
#  0.5259259259259259,
#  0.6454545454545454,
#  0.7999999999999999,
#  0.7125,
#  0.75,
#  0.9,
#  0.6357142857142857,
#  0.7839285714285715,
#  0.5,
#  0.9,
#  0.7,
#  0.7255102040816326,
#  0.2,
#  0.5031712473572939,
#  0.5259259259259259,
#  1.0,
#  0.5214285714285714,
#  0.5,
#  0.5322916666666667,
#  0.5031712473572939,
#  0.5820000000000001,
#  0.5,
#  0.75,
#  0.2,
#  0.5,
#  0.5700000000000001,
#  0.75,
#  0.5637096774193548,
#  0.5,
#  0.2,
#  0.6071428571428571,
#  0.55,
#  0.2,
#  0.485,
#  0.57125,
#  0.7111111111111111,
#  0.7216666666666666,
#  0.625,
#  0.4714285714285715,
#  0.95,
#  0.651048951048951,
#  0.2,
#  0.36,
#  0.5031712473572939,
#  0.4,
#  0.2,
#  0.7476993865030674,
#  0.5104072398190046,
#  0.6964285714285714,
#  0.7216666666666666,
#  0.55,
#  0.5104072398190046,
#  0.44333333333333336,
#  0.5031712473572939,
#  0.5,
#  0.5031712473572939,
#  0.640909090909091,
#  0.7702127659574469,
#  0.573076923076923,
#  0.7986486486486487,
#  0.7956521739130435,
#  0.9,
#  0.555,
#  0.7702127659574469,
#  0.7333333333333333,
#  0.7441176470588236,
#  0.7476993865030674,
#  0.63,
#  0.65125,
#  0.6875,
#  0.9,
#  0.6113013698630136,
#  0.5,
#  0.425,
#  0.7999999999999999,
#  0.6093333333333334,
#  0.7666666666666666,
#  0.5763565891472868,
#  0.573076923076923,
#  0.6093333333333334,
#  0.61,
#  0.2,
#  0.7333333333333333,
#  0.7071428571428572,
#  0.6000000000000001,
#  0.5763565891472868,
#  0.35000000000000003,
#  0.9,
#  0.4714285714285715,
#  0.9125,
#  0.5031712473572939,
#  0.651048951048951,
#  0.4983870967741935,
#  0.8142857142857143,
#  0.65125,
#  0.6789473684210526,
#  0.5031712473572939,
#  0.5007692307692307,
#  0.5599999999999999,
#  0.651048951048951,
#  0.4583333333333333,
#  0.9,
#  0.6736111111111112,
#  0.6109375,
#  0.6086956521739131,
#  0.72,
#  0.5,
#  0.5700000000000001,
#  0.5,
#  0.9125,
#  0.7208333333333333,
#  0.7986486486486487,
#  0.78125,
#  0.5763565891472868,
#  0.5763565891472868,
#  0.5,
#  0.6,
#  0.4916666666666667,
#  0.8333333333333334,
#  0.5007692307692307,
#  0.6130434782608696,
#  0.6431818181818182,
#  0.475,
#  0.9,
#  0.55,
#  0.75625,
#  0.659375,
#  0.5763565891472868,
#  0.6722222222222222,
#  1.0,
#  0.2,
#  0.6846846846846847,
#  0.5,
#  0.5637096774193548,
#  0.6875,
#  0.5263888888888889,
#  0.5031712473572939,
#  0.651048951048951,
#  0.5,
#  0.7278846153846155,
#  0.5031712473572939,
#  0.48333333333333334,
#  0.5259259259259259,
#  0.5,
#  0.6848484848484849,
#  0.5322916666666667,
#  0.5,
#  0.5031712473572939,
#  0.5,
#  0.5031712473572939,
#  0.46774193548387094,
#  0.651048951048951,
#  0.7916666666666666,
#  0.7839285714285715,
#  0.555,
#  0.875,
#  0.5637096774193548,
#  0.46774193548387094,
#  0.43,
#  0.6130434782608696,
#  0.9,
#  0.75,
#  0.9,
#  0.2,
#  0.6185185185185185,
#  0.5,
#  0.5875,
#  0.6666666666666666,
#  0.6849056603773584,
#  0.425,
#  0.5,
#  0.31500000000000006,
#  0.6214285714285713,
#  0.5875,
#  0.7702127659574469,
#  0.75,
#  0.35,
#  0.7476993865030674,
#  0.8625,
#  0.5083333333333333,
#  0.752,
#  0.5031712473572939,
#  0.55,
#  0.51,
#  0.5,
#  0.7,
#  0.5,
#  0.75,
#  0.75,
#  0.5,
#  0.4462962962962963,
#  0.5192307692307693,
#  0.75,
#  0.9125,
#  0.6261904761904762,
#  0.6333333333333333,
#  0.75,
#  0.2,
#  0.6166666666666667,
#  0.6848484848484849,
#  1.0,
#  0.5,
#  0.6848484848484849,
#  0.5938271604938272,
#  0.95,
#  0.65125,
#  0.6849056603773584,
#  0.7,
#  0.5407692307692308,
#  0.7777777777777778,
#  0.5111111111111111,
#  0.5031712473572939,
#  0.7666666666666666,
#  0.5031712473572939,
#  0.4125,
#  0.725,
#  0.48333333333333334,
#  0.2,
#  0.7250000000000001,
#  0.5666666666666667,
#  0.32,
#  0.9125,
#  0.5125,
#  0.6125,
#  0.5041666666666667,
#  0.65125,
#  0.6333333333333333,
#  0.5875,
#  0.6722222222222222,
#  0.7278846153846155,
#  0.8142857142857143,
#  0.825,
#  0.5863636363636364,
#  0.5805555555555555,
#  0.6166666666666667,
#  0.65,
#  0.39999999999999997,
#  0.75,
#  0.5031712473572939,
#  0.5,
#  0.825,
#  0.5136363636363637,
#  0.8826923076923077,
#  0.7476993865030674,
#  0.5333333333333333,
#  0.651048951048951,
#  0.63,
#  0.6431818181818182,
#  0.7,
#  0.55,
#  0.9,
#  0.5007692307692307,
#  0.5031712473572939,
#  0.5,
#  0.5,
#  0.6875,
#  0.655,
#  0.75,
#  0.35,
#  0.651048951048951,
#  0.5,
#  0.8625,
#  0.5031712473572939,
#  0.6166666666666667,
#  0.5104072398190046,
#  0.68,
#  0.5031712473572939,
#  0.4833333333333333,
#  0.6884615384615385,
#  0.7476993865030674,
#  0.46774193548387094,
#  0.7278846153846155,
#  0.9333333333333332,
#  0.46774193548387094,
#  0.5637096774193548,
#  0.51,
#  0.5,
#  0.7985294117647058,
#  0.85,
#  0.6428571428571429,
#  0.825,
#  0.5,
#  0.61875,
#  0.8333333333333334,
#  0.6416666666666667,
#  0.5375000000000001,
#  0.6916666666666668,
#  0.5938271604938272,
#  0.75,
#  0.9,
#  0.7321428571428571,
#  0.46829268292682924,
#  0.555952380952381,
#  0.8142857142857143,
#  0.75,
#  0.7255102040816326,
#  0.2,
#  0.5,
#  0.485,
#  0.5,
#  0.9,
#  0.7250000000000001,
#  0.5833333333333334,
#  0.5214285714285715,
#  0.5,
#  0.5,
#  0.9,
#  0.4111111111111111,
#  0.9,
#  0.2,
#  0.6333333333333333,
#  0.5692982456140352,
#  0.555952380952381,
#  0.7476993865030674,
#  0.875,
#  0.4555555555555555,
#  0.6285714285714286,
#  0.6093333333333334,
#  0.625,
#  0.555952380952381,
#  0.4983870967741935,
#  0.5923076923076922,
#  0.7321428571428571,
#  0.5142857142857143,
#  0.2,
#  0.5,
#  0.95,
#  0.5259259259259259,
#  0.5,
#  0.5031712473572939,
#  0.7208333333333333,
#  0.9,
#  0.5875,
#  0.65125,
#  0.5,
#  0.6736111111111112,
#  0.5,
#  0.445,
#  0.4462962962962963,
#  0.5104072398190046,
#  0.5031712473572939,
#  0.5104072398190046,
#  0.573076923076923,
#  0.65,
#  0.57125,
#  0.61875,
#  0.5599999999999999,
#  0.6,
#  0.3,
#  0.5104072398190046,
#  0.5031712473572939,
#  0.625,
#  0.9125,
#  0.2,
#  0.475,
#  0.85,
#  0.5,
#  0.9,
#  0.4035714285714286,
#  0.5104072398190046,
#  0.5,
#  0.7476993865030674,
#  0.4983870967741935,
#  0.2,
#  0.6416666666666667,
#  0.78,
#  0.5763565891472868,
#  0.9,
#  0.5031712473572939,
#  0.5954545454545456,
#  0.6599999999999999,
#  0.5322916666666667,
#  0.6958333333333333,
#  0.35,
#  0.42500000000000004,
#  0.7277777777777779,
#  0.6617647058823529,
#  0.5637096774193548,
#  0.5820000000000001,
#  0.5692982456140352,
#  0.4972222222222223,
#  0.5763565891472868,
#  0.5031712473572939,
#  0.7255102040816326,
#  0.5031712473572939,
#  0.9,
#  0.6849056603773584,
#  0.3,
#  0.625,
#  0.5031712473572939,
#  0.75,
#  0.8826923076923077,
#  0.9,
#  0.5407692307692308,
#  0.6642857142857144,
#  0.51,
#  0.6093333333333334,
#  0.55,
#  0.573076923076923,
#  0.3,
#  0.6166666666666667,
#  0.5,
#  0.7333333333333333,
#  0.6214285714285713,
#  0.5444444444444445,
#  0.64375,
#  0.6958333333333333,
#  0.71,
#  0.95,
#  0.5599999999999999,
#  0.6130434782608696,
#  0.5031712473572939,
#  0.85,
#  0.44999999999999996,
#  0.8333333333333334,
#  0.5,
#  0.6566666666666667,
#  0.7476993865030674,
#  0.6711538461538461,
#  0.5,
#  0.5058823529411764,
#  0.5263888888888889,
#  0.5938271604938272,
#  0.5428571428571428,
#  0.5916666666666667,
#  0.7255102040816326,
#  0.5,
#  0.6261904761904762,
#  0.41590909090909095,
#  0.6033333333333334,
#  0.5,
#  0.6382352941176471,
#  0.9,
#  0.75,
#  0.8826923076923077,
#  1.0,
#  0.9,
#  0.75,
#  0.64375,
#  0.43,
#  0.48,
#  0.6133333333333333,
#  0.5104072398190046,
#  0.5031712473572939,
#  0.6033333333333334,
#  0.5829268292682926,
#  0.41875,
#  0.66,
#  0.4125,
#  0.573076923076923,
#  0.35,
#  0.9,
#  0.6736111111111112,
#  0.2,
#  0.35,
#  0.9125,
#  0.5031712473572939,
#  0.6763157894736842,
#  0.625,
#  0.6109375,
#  0.9,
#  0.4428571428571429,
#  0.651048951048951,
#  0.6409090909090909,
#  0.5031712473572939,
#  0.2,
#  0.35,
#  0.46774193548387094,
#  0.5031712473572939,
#  0.555952380952381,
#  0.9,
#  0.35,
#  0.6166666666666667,
#  0.5285714285714286,
#  0.75,
#  0.35,
#  0.475,
#  0.7999999999999999,
#  0.5692982456140352,
#  0.5954545454545456,
#  0.7250000000000001,
#  0.5763565891472868,
#  0.2,
#  0.6892857142857143,
#  0.7255102040816326,
#  0.39999999999999997,
#  0.5,
#  0.6382352941176471,
#  0.525,
#  0.2,
#  0.57125,
#  0.5104072398190046,
#  0.5,
#  0.5031712473572939,
#  0.7476993865030674,
#  0.651048951048951,
#  0.9,
#  0.6382352941176471,
#  0.5333333333333333,
#  0.49000000000000005,
#  0.6849056603773584,
#  0.9125,
#  0.75,
#  0.7476993865030674,
#  0.9,
#  0.7986486486486487,
#  0.6722222222222222,
#  0.5104072398190046,
#  0.61875,
#  0.9125,
#  0.61875,
#  0.9,
#  0.9,
#  0.6166666666666667,
#  0.5,
#  0.5227272727272727,
#  0.9,
#  0.9,
#  0.6416666666666667,
#  0.61,
#  0.2,
#  0.5637096774193548,
#  0.6892857142857143,
#  0.9500000000000001,
#  0.4714285714285715,
#  1.0,
#  0.41875,
#  0.2,
#  0.7476993865030674,
#  0.5,
#  0.61,
#  0.5346153846153846,
#  0.8142857142857143,
#  0.75,
#  0.7476993865030674,
#  0.2,
#  0.825,
#  0.6849056603773584,
#  0.5031712473572939,
#  0.5133333333333333,
#  0.8517857142857144,
#  1.0,
#  0.5031712473572939,
#  0.7702127659574469,
#  0.6884615384615385,
#  0.20000000000000004,
#  0.6185185185185185,
#  0.4833333333333333,
#  0.35,
#  0.625,
#  0.75,
#  0.5687500000000001,
#  0.5,
#  0.8826923076923077,
#  0.2,
#  0.6681818181818181,
#  0.5104072398190046,
#  0.2,
#  0.7476993865030674,
#  0.5031712473572939,
#  0.61,
#  0.8333333333333334,
#  0.7702127659574469,
#  0.6454545454545454,
#  0.5938271604938272,
#  0.5,
#  0.7222222222222222,
#  0.46774193548387094,
#  0.651048951048951,
#  0.6431818181818182,
#  0.7875,
#  0.48888888888888893,
#  0.6261904761904762,
#  0.6848484848484849,
#  0.4125,
#  0.5031712473572939,
#  0.73,
#  0.5,
#  0.5763565891472868,
#  0.6846846846846847,
#  0.5938271604938272,
#  0.4428571428571429,
#  0.485,
#  0.5,
#  0.625,
#  0.7318181818181819,
#  0.6285714285714286,
#  0.5407692307692308,
#  0.5666666666666667,
#  0.75,
#  0.9,
#  0.61,
#  0.9125,
#  0.5923076923076922,
#  0.9,
#  0.6214285714285713,
#  0.9,
#  0.73,
#  0.9,
#  0.45,
#  0.6,
#  0.5007692307692307,
#  1.0,
#  0.6566666666666667,
#  0.825,
#  0.5,
#  0.6093333333333334,
#  0.5692982456140352,
#  0.2,
#  0.5863636363636364,
#  0.7227272727272728,
#  0.75,
#  0.65125,
#  0.75,
#  0.48333333333333334,
#  0.6849056603773584,
#  0.2,
#  0.8333333333333334,
#  0.555,
#  0.46774193548387094,
#  0.6711538461538461,
#  0.9,
#  0.9,
#  0.5938271604938272,
#  0.7,
#  0.65625,
#  0.9,
#  0.75,
#  0.5058823529411764,
#  0.6000000000000001,
#  0.75,
#  0.7666666666666666,
#  0.4983870967741935,
#  0.6636363636363637,
#  0.48333333333333334,
#  0.6763157894736842,
#  0.7625,
#  0.2,
#  0.61875,
#  0.5,
#  0.7875,
#  0.5,
#  0.5031712473572939,
#  0.55,
#  0.5375000000000001,
#  0.725,
#  0.7476993865030674,
#  0.6113013698630136,
#  0.6763157894736842,
#  0.7255102040816326,
#  0.6846846846846847,
#  0.6722222222222222,
#  0.65625,
#  0.7702127659574469,
#  0.701851851851852,
#  0.75,
#  0.5031712473572939,
#  0.2,
#  0.5104072398190046,
#  0.925,
#  0.5322916666666667,
#  0.6846846846846847,
#  0.625,
#  0.5,
#  0.5,
#  0.75,
#  0.61875,
#  0.3,
#  0.46774193548387094,
#  0.7476993865030674,
#  0.5031712473572939,
#  0.5,
#  0.5,
#  0.5259259259259259,
#  0.6409090909090909,
#  0.5104072398190046,
#  0.35,
#  0.46774193548387094,
#  0.75,
#  0.3,
#  0.75,
#  0.61875,
#  0.7166666666666667,
#  1.0,
#  0.5333333333333333,
#  0.6093333333333334,
#  0.555952380952381,
#  0.7166666666666667,
#  0.5031712473572939,
#  0.825,
#  1.0,
#  0.8826923076923077,
#  0.5,
#  0.7333333333333333,
#  0.44333333333333336,
#  0.6846846846846847,
#  0.4666666666666667,
#  1.0,
#  0.5763565891472868,
#  0.7255102040816326,
#  0.6093333333333334,
#  0.5104072398190046,
#  0.75,
#  0.4166666666666667,
#  0.5031712473572939,
#  0.6133333333333333,
#  0.8444444444444444,
#  0.6086956521739131,
#  0.8826923076923077,
#  0.5007692307692307,
#  0.6599999999999999,
#  0.64375,
#  0.9,
#  0.2,
#  0.5829268292682926,
#  0.4972222222222223,
#  0.5259259259259259,
#  0.525,
#  0.7986486486486487,
#  0.49090909090909096,
#  0.2,
#  0.55,
#  0.5,
#  0.61875,
#  0.5666666666666667,
#  0.55,
#  0.6033333333333334,
#  0.55,
#  0.7307692307692307,
#  0.6214285714285713,
#  0.61875,
#  0.5031712473572939,
#  0.6846846846846847,
#  0.6285714285714286,
#  0.46249999999999997,
#  0.7255102040816326,
#  0.7476993865030674,
#  0.6093333333333334,
#  0.9,
#  0.7388888888888888,
#  0.875,
#  0.5333333333333333,
#  0.4375,
#  0.6958333333333333,
#  0.6093333333333334,
#  0.8625,
#  0.9,
#  0.5104072398190046,
#  0.701851851851852,
#  0.5,
#  0.5829268292682926,
#  0.6636363636363637,
#  0.9125,
#  0.20000000000000004,
#  0.6113013698630136,
#  0.7,
#  0.573076923076923,
#  0.5104072398190046,
#  0.9,
#  0.5,
#  0.5031712473572939,
#  0.6711538461538461,
#  0.8142857142857143,
#  0.6636363636363637,
#  0.540625,
#  0.7956521739130435,
#  0.75,
#  0.5938271604938272,
#  0.4125,
#  0.7,
#  0.5,
#  0.375,
#  0.5833333333333334,
#  0.5,
#  0.5104072398190046,
#  0.6,
#  0.9125,
#  0.5666666666666667,
#  0.6071428571428571,
#  0.61875,
#  0.5923076923076922,
#  0.5031712473572939,
#  0.55,
#  0.4972222222222223,
#  0.5031712473572939,
#  0.6954545454545454,
#  0.9125,
#  0.6086956521739131,
#  0.5599999999999999,
#  0.8142857142857143,
#  0.75625,
#  0.5,
#  0.8021739130434782,
#  1.0,
#  0.9,
#  0.5104072398190046,
#  0.5266666666666667,
#  0.5,
#  0.475,
#  ...]

# %%
def to_onehot(a):
    a_cat = [0]*len(a)
    for i in range(len(a)):
        if a[i]=='true':
            a_cat[i] = [1,0,0,0,0,0]
        elif a[i]=='mostly-true':
            a_cat[i] = [0,1,0,0,0,0]
        elif a[i]=='half-true':
            a_cat[i] = [0,0,1,0,0,0]
        elif a[i]=='barely-true':
            a_cat[i] = [0,0,0,1,0,0]
        elif a[i]=='false':
            a_cat[i] = [0,0,0,0,1,0]
        elif a[i]=='pants-fire':
            a_cat[i] = [0,0,0,0,0,1]
        else:
            print('Incorrect label')
    return a_cat

def to_onehot(a):
    a_cat = [0]*len(a)
    for i in range(len(a)):
        if a[i]=='true':
            a_cat[i] = [1,0]
        elif a[i]=='mostly-true':
            a_cat[i] = [1,0]
        elif a[i]=='half-true':
            a_cat[i] = [1,0]
        elif a[i]=='barely-true':
            a_cat[i] = [0,1]
        elif a[i]=='false':
            a_cat[i] = [0,1]
        elif a[i]=='pants-fire':
            a_cat[i] = [0,1]
        else:
            print('Incorrect label')
    return a_cat

# %%
labels_onehot = {'train':to_onehot(labels['train']), 'test':to_onehot(labels['test']), 'val':to_onehot(labels['val'])}

# %%
class BertLayerNorm(nn.Module):
        def __init__(self, hidden_size, eps=1e-12):
            """Construct a layernorm module in the TF style (epsilon inside the square root).
            """
            super(BertLayerNorm, self).__init__()
            self.weight = nn.Parameter(torch.ones(hidden_size))
            self.bias = nn.Parameter(torch.zeros(hidden_size))
            self.variance_epsilon = eps

        def forward(self, x):
            u = x.mean(-1, keepdim=True)
            s = (x - u).pow(2).mean(-1, keepdim=True)
            x = (x - u) / torch.sqrt(s + self.variance_epsilon)
            return self.weight * x + self.bias
        

class BertForSequenceClassification(nn.Module):
    """BERT model for classification.
    This module is composed of the BERT model with a linear layer on top of
    the pooled output.
    Params:
        `config`: a BertConfig class instance with the configuration to build a new model.
        `num_labels`: the number of classes for the classifier. Default = 2.
    Inputs:
        `input_ids`: a torch.LongTensor of shape [batch_size, sequence_length]
            with the word token indices in the vocabulary. Items in the batch should begin with the special "CLS" token. (see the tokens preprocessing logic in the scripts
            `extract_features.py`, `run_classifier.py` and `run_squad.py`)
        `token_type_ids`: an optional torch.LongTensor of shape [batch_size, sequence_length] with the token
            types indices selected in [0, 1]. Type 0 corresponds to a `sentence A` and type 1 corresponds to
            a `sentence B` token (see BERT paper for more details).
        `attention_mask`: an optional torch.LongTensor of shape [batch_size, sequence_length] with indices
            selected in [0, 1]. It's a mask to be used if the input sequence length is smaller than the max
            input sequence length in the current batch. It's the mask that we typically use for attention when
            a batch has varying length sentences.
        `labels`: labels for the classification output: torch.LongTensor of shape [batch_size]
            with indices selected in [0, ..., num_labels].
    Outputs:
        if `labels` is not `None`:
            Outputs the CrossEntropy classification loss of the output with the labels.
        if `labels` is `None`:
            Outputs the classification logits of shape [batch_size, num_labels].
    Example usage:
    ```python
    # Already been converted into WordPiece token ids
    input_ids = torch.LongTensor([[31, 51, 99], [15, 5, 0]])
    input_mask = torch.LongTensor([[1, 1, 1], [1, 1, 0]])
    token_type_ids = torch.LongTensor([[0, 0, 1], [0, 1, 0]])
    config = BertConfig(vocab_size_or_config_json_file=32000, hidden_size=768,
        num_hidden_layers=12, num_attention_heads=12, intermediate_size=3072)
    num_labels = 2
    model = BertForSequenceClassification(config, num_labels)
    logits = model(input_ids, token_type_ids, input_mask)
    ```
    """
    def __init__(self, num_labels=2): # Change number of labels here.
        super(BertForSequenceClassification, self).__init__()
        self.num_labels = num_labels
        self.bert = BertModel.from_pretrained('bert-base-uncased')
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size*3, num_labels)
        #self.fc1 = nn.Linear(config.hidden_size*2, 512)
        nn.init.xavier_normal_(self.classifier.weight)
        
    '''def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output'''
        
    def forward_once(self, input_ids, token_type_ids=None, attention_mask=None, labels=None):
        _, pooled_output = self.bert(input_ids, token_type_ids, attention_mask, output_all_encoded_layers=False)
        pooled_output = self.dropout(pooled_output)
        #logits = self.classifier(pooled_output)

        return pooled_output
    
    def forward(self, input_ids1, input_ids2, input_ids3, credit_sc):
        # forward pass of input 1
        output1 = self.forward_once(input_ids1, token_type_ids=None, attention_mask=None, labels=None)
        # forward pass of input 2
        output2 = self.forward_once(input_ids2, token_type_ids=None, attention_mask=None, labels=None)
        
        output3 = self.forward_once(input_ids3, token_type_ids=None, attention_mask=None, labels=None)
        
        out = torch.cat((output1, output2, output3), 1)
        
        # Multiply the credit score with the output after concatnation
        
        out = torch.mul(credit_sc, out)
        
        #out = self.fc1(out)
        logits = self.classifier(out)
        
        return logits
    
    def freeze_bert_encoder(self):
        for param in self.bert.parameters():
            param.requires_grad = False
    
    def unfreeze_bert_encoder(self):
        for param in self.bert.parameters():
            param.requires_grad = True

# %%
from pytorch_pretrained_bert import BertConfig

config = BertConfig(vocab_size_or_config_json_file=32000, hidden_size=768,
        num_hidden_layers=12, num_attention_heads=12, intermediate_size=3072)

num_labels = 2
model = BertForSequenceClassification(num_labels)

# Convert inputs to PyTorch tensors
tokens_tensor = torch.tensor([tokenizer.convert_tokens_to_ids(zz)])

logits = model(tokens_tensor, tokens_tensor, tokens_tensor, x)
# Out:
# INFO:pytorch_pretrained_bert.modeling:loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at /home/ubuntu/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# INFO:pytorch_pretrained_bert.modeling:extracting archive file /home/ubuntu/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /tmp/tmpu2foyag2
# INFO:pytorch_pretrained_bert.modeling:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }

# %%
tokens_tensor
# Out:
# tensor([[ 2054,  2003,  1037, 16405, 25619]])

# %%
logits
# Out:
# tensor([[-0.2923,  0.2326]], grad_fn=<AddmmBackward>)

# %%
import pandas as pd

dat = pd.read_csv('/home/ubuntu/fake_news/custom_bert_pipeline/IMDB Dataset.csv')

# %%
dat.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
zz = tokenizer.tokenize(dat.review[1])
z1z = tokenizer.tokenize(dat.review[3])

[zz,z1z ]
# Out:
# [['a',
#   'wonderful',
#   'little',
#   'production',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   'the',
#   'filming',
#   'technique',
#   'is',
#   'very',
#   'una',
#   '##ss',
#   '##uming',
#   '-',
#   'very',
#   'old',
#   '-',
#   'time',
#   '-',
#   'bbc',
#   'fashion',
#   'and',
#   'gives',
#   'a',
#   'comforting',
#   ',',
#   'and',
#   'sometimes',
#   'discomfort',
#   '##ing',
#   ',',
#   'sense',
#   'of',
#   'realism',
#   'to',
#   'the',
#   'entire',
#   'piece',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   'the',
#   'actors',
#   'are',
#   'extremely',
#   'well',
#   'chosen',
#   '-',
#   'michael',
#   'sheen',
#   'not',
#   'only',
#   '"',
#   'has',
#   'got',
#   'all',
#   'the',
#   'polar',
#   '##i',
#   '"',
#   'but',
#   'he',
#   'has',
#   'all',
#   'the',
#   'voices',
#   'down',
#   'pat',
#   'too',
#   '!',
#   'you',
#   'can',
#   'truly',
#   'see',
#   'the',
#   'seam',
#   '##less',
#   'editing',
#   'guided',
#   'by',
#   'the',
#   'references',
#   'to',
#   'williams',
#   "'",
#   'diary',
#   'entries',
#   ',',
#   'not',
#   'only',
#   'is',
#   'it',
#   'well',
#   'worth',
#   'the',
#   'watching',
#   'but',
#   'it',
#   'is',
#   'a',
#   'terrific',
#   '##ly',
#   'written',
#   'and',
#   'performed',
#   'piece',
#   '.',
#   'a',
#   'master',
#   '##ful',
#   'production',
#   'about',
#   'one',
#   'of',
#   'the',
#   'great',
#   'master',
#   "'",
#   's',
#   'of',
#   'comedy',
#   'and',
#   'his',
#   'life',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   'the',
#   'realism',
#   'really',
#   'comes',
#   'home',
#   'with',
#   'the',
#   'little',
#   'things',
#   ':',
#   'the',
#   'fantasy',
#   'of',
#   'the',
#   'guard',
#   'which',
#   ',',
#   'rather',
#   'than',
#   'use',
#   'the',
#   'traditional',
#   "'",
#   'dream',
#   "'",
#   'techniques',
#   'remains',
#   'solid',
#   'then',
#   'disappears',
#   '.',
#   'it',
#   'plays',
#   'on',
#   'our',
#   'knowledge',
#   'and',
#   'our',
#   'senses',
#   ',',
#   'particularly',
#   'with',
#   'the',
#   'scenes',
#   'concerning',
#   'orton',
#   'and',
#   'hall',
#   '##i',
#   '##well',
#   'and',
#   'the',
#   'sets',
#   '(',
#   'particularly',
#   'of',
#   'their',
#   'flat',
#   'with',
#   'hall',
#   '##i',
#   '##well',
#   "'",
#   's',
#   'murals',
#   'decor',
#   '##ating',
#   'every',
#   'surface',
#   ')',
#   'are',
#   'terribly',
#   'well',
#   'done',
#   '.'],
#  ['basically',
#   'there',
#   "'",
#   's',
#   'a',
#   'family',
#   'where',
#   'a',
#   'little',
#   'boy',
#   '(',
#   'jake',
#   ')',
#   'thinks',
#   'there',
#   "'",
#   's',
#   'a',
#   'zombie',
#   'in',
#   'his',
#   'closet',
#   '&',
#   'his',
#   'parents',
#   'are',
#   'fighting',
#   'all',
#   'the',
#   'time',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   'this',
#   'movie',
#   'is',
#   'slower',
#   'than',
#   'a',
#   'soap',
#   'opera',
#   '.',
#   '.',
#   '.',
#   'and',
#   'suddenly',
#   ',',
#   'jake',
#   'decides',
#   'to',
#   'become',
#   'ram',
#   '##bo',
#   'and',
#   'kill',
#   'the',
#   'zombie',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   'ok',
#   ',',
#   'first',
#   'of',
#   'all',
#   'when',
#   'you',
#   "'",
#   're',
#   'going',
#   'to',
#   'make',
#   'a',
#   'film',
#   'you',
#   'must',
#   'decide',
#   'if',
#   'its',
#   'a',
#   'thriller',
#   'or',
#   'a',
#   'drama',
#   '!',
#   'as',
#   'a',
#   'drama',
#   'the',
#   'movie',
#   'is',
#   'watch',
#   '##able',
#   '.',
#   'parents',
#   'are',
#   'di',
#   '##vor',
#   '##cing',
#   '&',
#   'arguing',
#   'like',
#   'in',
#   'real',
#   'life',
#   '.',
#   'and',
#   'then',
#   'we',
#   'have',
#   'jake',
#   'with',
#   'his',
#   'closet',
#   'which',
#   'totally',
#   'ruins',
#   'all',
#   'the',
#   'film',
#   '!',
#   'i',
#   'expected',
#   'to',
#   'see',
#   'a',
#   'boo',
#   '##ge',
#   '##yman',
#   'similar',
#   'movie',
#   ',',
#   'and',
#   'instead',
#   'i',
#   'watched',
#   'a',
#   'drama',
#   'with',
#   'some',
#   'meaningless',
#   'thriller',
#   'spots',
#   '.',
#   '<',
#   'br',
#   '/',
#   '>',
#   '<',
#   'br',
#   '/',
#   '>',
#   '3',
#   'out',
#   'of',
#   '10',
#   'just',
#   'for',
#   'the',
#   'well',
#   'playing',
#   'parents',
#   '&',
#   'descent',
#   'dial',
#   '##og',
#   '##s',
#   '.',
#   'as',
#   'for',
#   'the',
#   'shots',
#   'with',
#   'jake',
#   ':',
#   'just',
#   'ignore',
#   'them',
#   '.']]

# %%
zzz = tokenizer.convert_tokens_to_ids(zz)
zzzz = tokenizer.convert_tokens_to_ids(z1z)

# %%
zzz
# Out:
# [1037,
#  6919,
#  2210,
#  2537,
#  1012,
#  1026,
#  7987,
#  1013,
#  1028,
#  1026,
#  7987,
#  1013,
#  1028,
#  1996,
#  7467,
#  6028,
#  2003,
#  2200,
#  14477,
#  4757,
#  24270,
#  1011,
#  2200,
#  2214,
#  1011,
#  2051,
#  1011,
#  4035,
#  4827,
#  1998,
#  3957,
#  1037,
#  16334,
#  1010,
#  1998,
#  2823,
#  17964,
#  2075,
#  1010,
#  3168,
#  1997,
#  15650,
#  2000,
#  1996,
#  2972,
#  3538,
#  1012,
#  1026,
#  7987,
#  1013,
#  1028,
#  1026,
#  7987,
#  1013,
#  1028,
#  1996,
#  5889,
#  2024,
#  5186,
#  2092,
#  4217,
#  1011,
#  2745,
#  20682,
#  2025,
#  2069,
#  1000,
#  2038,
#  2288,
#  2035,
#  1996,
#  11508,
#  2072,
#  1000,
#  2021,
#  2002,
#  2038,
#  2035,
#  1996,
#  5755,
#  2091,
#  6986,
#  2205,
#  999,
#  2017,
#  2064,
#  5621,
#  2156,
#  1996,
#  25180,
#  3238,
#  9260,
#  8546,
#  2011,
#  1996,
#  7604,
#  2000,
#  3766,
#  1005,
#  9708,
#  10445,
#  1010,
#  2025,
#  2069,
#  2003,
#  2009,
#  2092,
#  4276,
#  1996,
#  3666,
#  2021,
#  2009,
#  2003,
#  1037,
#  27547,
#  2135,
#  2517,
#  1998,
#  2864,
#  3538,
#  1012,
#  1037,
#  3040,
#  3993,
#  2537,
#  2055,
#  2028,
#  1997,
#  1996,
#  2307,
#  3040,
#  1005,
#  1055,
#  1997,
#  4038,
#  1998,
#  2010,
#  2166,
#  1012,
#  1026,
#  7987,
#  1013,
#  1028,
#  1026,
#  7987,
#  1013,
#  1028,
#  1996,
#  15650,
#  2428,
#  3310,
#  2188,
#  2007,
#  1996,
#  2210,
#  2477,
#  1024,
#  1996,
#  5913,
#  1997,
#  1996,
#  3457,
#  2029,
#  1010,
#  2738,
#  2084,
#  2224,
#  1996,
#  3151,
#  1005,
#  3959,
#  1005,
#  5461,
#  3464,
#  5024,
#  2059,
#  17144,
#  1012,
#  2009,
#  3248,
#  2006,
#  2256,
#  3716,
#  1998,
#  2256,
#  9456,
#  1010,
#  3391,
#  2007,
#  1996,
#  5019,
#  7175,
#  25161,
#  1998,
#  2534,
#  2072,
#  4381,
#  1998,
#  1996,
#  4520,
#  1006,
#  3391,
#  1997,
#  2037,
#  4257,
#  2007,
#  2534,
#  2072,
#  4381,
#  1005,
#  1055,
#  19016,
#  25545,
#  5844,
#  2296,
#  3302,
#  1007,
#  2024,
#  16668,
#  2092,
#  2589,
#  1012]

# %%
tokens_tensor = torch.tensor([zzz,zzz])

# %%
tokens_tensor
# Out:
# tensor([[ 1037,  6919,  2210,  2537,  1012,  1026,  7987,  1013,  1028,  1026,
#           7987,  1013,  1028,  1996,  7467,  6028,  2003,  2200, 14477,  4757,
#          24270,  1011,  2200,  2214,  1011,  2051,  1011,  4035,  4827,  1998,
#           3957,  1037, 16334,  1010,  1998,  2823, 17964,  2075,  1010,  3168,
#           1997, 15650,  2000,  1996,  2972,  3538,  1012,  1026,  7987,  1013,
#           1028,  1026,  7987,  1013,  1028,  1996,  5889,  2024,  5186,  2092,
#           4217,  1011,  2745, 20682,  2025,  2069,  1000,  2038,  2288,  2035,
#           1996, 11508,  2072,  1000,  2021,  2002,  2038,  2035,  1996,  5755,
#           2091,  6986,  2205,   999,  2017,  2064,  5621,  2156,  1996, 25180,
#           3238,  9260,  8546,  2011,  1996,  7604,  2000,  3766,  1005,  9708,
#          10445,  1010,  2025,  2069,  2003,  2009,  2092,  4276,  1996,  3666,
#           2021,  2009,  2003,  1037, 27547,  2135,  2517,  1998,  2864,  3538,
#           1012,  1037,  3040,  3993,  2537,  2055,  2028,  1997,  1996,  2307,
#           3040,  1005,  1055,  1997,  4038,  1998,  2010,  2166,  1012,  1026,
#           7987,  1013,  1028,  1026,  7987,  1013,  1028,  1996, 15650,  2428,
#           3310,  2188,  2007,  1996,  2210,  2477,  1024,  1996,  5913,  1997,
#           1996,  3457,  2029,  1010,  2738,  2084,  2224,  1996,  3151,  1005,
#           3959,  1005,  5461,  3464,  5024,  2059, 17144,  1012,  2009,  3248,
#           2006,  2256,  3716,  1998,  2256,  9456,  1010,  3391,  2007,  1996,
#           5019,  7175, 25161,  1998,  2534,  2072,  4381,  1998,  1996,  4520,
#           1006,  3391,  1997,  2037,  4257,  2007,  2534,  2072,  4381,  1005,
#           1055, 19016, 25545,  5844,  2296,  3302,  1007,  2024, 16668,  2092,
#           2589,  1012],
#         [ 1037,  6919,  2210,  2537,  1012,  1026,  7987,  1013,  1028,  1026,
#           7987,  1013,  1028,  1996,  7467,  6028,  2003,  2200, 14477,  4757,
#          24270,  1011,  2200,  2214,  1011,  2051,  1011,  4035,  4827,  1998,
#           3957,  1037, 16334,  1010,  1998,  2823, 17964,  2075,  1010,  3168,
#           1997, 15650,  2000,  1996,  2972,  3538,  1012,  1026,  7987,  1013,
#           1028,  1026,  7987,  1013,  1028,  1996,  5889,  2024,  5186,  2092,
#           4217,  1011,  2745, 20682,  2025,  2069,  1000,  2038,  2288,  2035,
#           1996, 11508,  2072,  1000,  2021,  2002,  2038,  2035,  1996,  5755,
#           2091,  6986,  2205,   999,  2017,  2064,  5621,  2156,  1996, 25180,
#           3238,  9260,  8546,  2011,  1996,  7604,  2000,  3766,  1005,  9708,
#          10445,  1010,  2025,  2069,  2003,  2009,  2092,  4276,  1996,  3666,
#           2021,  2009,  2003,  1037, 27547,  2135,  2517,  1998,  2864,  3538,
#           1012,  1037,  3040,  3993,  2537,  2055,  2028,  1997,  1996,  2307,
#           3040,  1005,  1055,  1997,  4038,  1998,  2010,  2166,  1012,  1026,
#           7987,  1013,  1028,  1026,  7987,  1013,  1028,  1996, 15650,  2428,
#           3310,  2188,  2007,  1996,  2210,  2477,  1024,  1996,  5913,  1997,
#           1996,  3457,  2029,  1010,  2738,  2084,  2224,  1996,  3151,  1005,
#           3959,  1005,  5461,  3464,  5024,  2059, 17144,  1012,  2009,  3248,
#           2006,  2256,  3716,  1998,  2256,  9456,  1010,  3391,  2007,  1996,
#           5019,  7175, 25161,  1998,  2534,  2072,  4381,  1998,  1996,  4520,
#           1006,  3391,  1997,  2037,  4257,  2007,  2534,  2072,  4381,  1005,
#           1055, 19016, 25545,  5844,  2296,  3302,  1007,  2024, 16668,  2092,
#           2589,  1012]])

# %%
logits = model(tokens_tensor)
logits
# Out:
# tensor([[-0.2868, -0.2532,  0.2102,  0.2264, -0.3351, -1.7115],
#         [ 0.5625,  0.3654,  0.6102,  0.2430, -0.0879, -1.3481]],
#        grad_fn=<AddmmBackward>)

# %%
import torch.nn.functional as F

F.softmax(logits,dim=1)
# Out:
# tensor([[0.6739, 0.3261]], grad_fn=<SoftmaxBackward>)

# %%
'''from sklearn.model_selection import train_test_split
X = dat['review']
y = dat['sentiment']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)'''
# Out:
# "from sklearn.model_selection import train_test_split\nX = dat['review']\ny = dat['sentiment']\n\n\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)"

# %%
'''X_train = X_train.values.tolist()
X_test = X_test.values.tolist()

y_train = pd.get_dummies(y_train).values.tolist()
y_test = pd.get_dummies(y_test).values.tolist()'''
# Out:
# 'X_train = X_train.values.tolist()\nX_test = X_test.values.tolist()\n\ny_train = pd.get_dummies(y_train).values.tolist()\ny_test = pd.get_dummies(y_test).values.tolist()'

# %%
X_train = statements['train']
y_train = labels_onehot['train']

X_test = statements['val']
y_test = labels_onehot['val']

# %%
max_seq_length = 256
class text_dataset(Dataset):
    def __init__(self,x_y_list, transform=None):
        
        self.x_y_list = x_y_list
        self.transform = transform
        
    def __getitem__(self,index):
        
        tokenized_review = tokenizer.tokenize(self.x_y_list[0][index])
        
        if len(tokenized_review) > max_seq_length:
            tokenized_review = tokenized_review[:max_seq_length]
            
        ids_review  = tokenizer.convert_tokens_to_ids(tokenized_review)

        padding = [0] * (max_seq_length - len(ids_review))
        
        ids_review += padding
        
        assert len(ids_review) == max_seq_length
        
        #print(ids_review)
        ids_review = torch.tensor(ids_review)
        
        sentiment = self.x_y_list[1][index] # color        
        list_of_labels = [torch.from_numpy(np.array(sentiment))]
        
        
        return ids_review, list_of_labels[0]
    
    def __len__(self):
        return len(self.x_y_list[0])

# %%
batch_size = 16

train_lists = [X_train, y_train]
test_lists = [X_test, y_test]

training_dataset = text_dataset(x_y_list = train_lists )

test_dataset = text_dataset(x_y_list = test_lists )

dataloaders_dict = {'train': torch.utils.data.DataLoader(training_dataset, batch_size=batch_size, shuffle=True, num_workers=0),
                   'val':torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
                   }
dataset_sizes = {'train':len(train_lists[0]),
                'val':len(test_lists[0])}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    print('starting')
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 100

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            
            sentiment_corrects = 0
            
            
            # Iterate over data.
            for inputs, sentiment in dataloaders_dict[phase]:
                #inputs = inputs
                #print(len(inputs),type(inputs),inputs)
                #inputs = torch.from_numpy(np.array(inputs)).to(device) 
                inputs = inputs.to(device) 

                sentiment = sentiment.to(device)
                
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    #print(inputs)
                    outputs = model(inputs)

                    outputs = F.softmax(outputs,dim=1)
                    
                    loss = criterion(outputs, torch.max(sentiment.float(), 1)[1])
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)

                
                sentiment_corrects += torch.sum(torch.max(outputs, 1)[1] == torch.max(sentiment, 1)[1])

                
            epoch_loss = running_loss / dataset_sizes[phase]

            
            sentiment_acc = sentiment_corrects.double() / dataset_sizes[phase]

            print('{} total loss: {:.4f} '.format(phase,epoch_loss ))
            print('{} sentiment_acc: {:.4f}'.format(
                phase, sentiment_acc))

            if phase == 'val' and epoch_loss < best_loss:
                print('saving with loss of {}'.format(epoch_loss),
                      'improved over previous {}'.format(best_loss))
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), 'bert_model_test.pth')


        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(float(best_loss)))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): BertLayerNorm()
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1)
#   (classifier): Linear(in_features=768, out_features=6, bias=True)
# )

# %%
lrlast = .001
lrmain = .00001
optim1 = optim.Adam(
    [
        {"params":model.bert.parameters(),"lr": lrmain},
        {"params":model.classifier.parameters(), "lr": lrlast},
       
   ])

#optim1 = optim.Adam(model.parameters(), lr=0.001)#,momentum=.9)
# Observe that all parameters are being optimized
optimizer_ft = optim1
criterion = nn.CrossEntropyLoss()

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft1 = train_model(model, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=10)
# Out:
# starting
# Epoch 0/9
# ----------

# %%
from pathlib import Path

# %%
home = str(Path.home())

# %%
home
# Out:
# '/home/ubuntu'
